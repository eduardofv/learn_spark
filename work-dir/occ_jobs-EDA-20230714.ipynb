# %% [markdown]
# # Structure Check
#
# Cómo tener acceso a los JSON internos de los registros.
#
# Es necesario definir un schema. Abajo se ve cómo inferir schema a partir de un ejemplo

# %%
import pandas as pd
import matplotlib.pyplot as plt

import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F


spark = SparkSession \
    .builder \
    .appName("Learning Spark") \
    .getOrCreate()

#df = spark.read.json("harvester/occ/tests/test-gdl.jsonl")
#df = spark.read.json("harvester/occ/tests/test-cdmx/sneaky*.jsonl.gz")
#df = spark.read.json("test-cdmx.jsonl") #from ETL
#df = spark.read.json("test-full-occ.jsonl") #from ETL
df = spark.read.json("occ-20230714.jsonl")
categories = spark.read.json("categories.json")
subcategories = spark.read.json("subcategories.json")

# %%
#categories.count(), categories.printSchema()
#subcategories.show()

# %%
df.count(), df.printSchema()
# Out:
# root
#  |-- Job:value: string (nullable = true)
#  |-- __typename: string (nullable = true)
#  |-- applied: boolean (nullable = true)
#  |-- autoinclusion: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- autoinclusion: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |-- bullets: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- __ref: string (nullable = true)
#  |-- category: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- company: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- confidential: boolean (nullable = true)
#  |    |-- logoUrl: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- namePretty: string (nullable = true)
#  |    |-- profile: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- rel: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- contact: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- emailAddress: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- phoneNumber: string (nullable = true)
#  |    |-- showContactInfo: boolean (nullable = true)
#  |-- dates: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- active: string (nullable = true)
#  |    |-- expires: string (nullable = true)
#  |    |-- publish: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- education: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- level: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- friendlyId: string (nullable = true)
#  |-- googleForJobs: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- isGoogleForJobs: boolean (nullable = true)
#  |    |-- isGoogleIndexed: boolean (nullable = true)
#  |-- hiring: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- contract: boolean (nullable = true)
#  |    |-- fullTime: boolean (nullable = true)
#  |    |-- partTime: boolean (nullable = true)
#  |    |-- permanent: boolean (nullable = true)
#  |    |-- temporary: boolean (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- jobBody: string (nullable = true)
#  |-- jobType: string (nullable = true)
#  |-- level: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- location: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- locations: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- city: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- jobCity: string (nullable = true)
#  |    |    |    |    |-- rel: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- country: struct (nullable = true)
#  |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |-- locationId: string (nullable = true)
#  |    |    |    |-- placeId: string (nullable = true)
#  |    |    |    |-- state: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- abbreviation: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- rel: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- zone: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- profileId: string (nullable = true)
#  |-- redirect: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- externalUrl: string (nullable = true)
#  |    |-- isRedirected: boolean (nullable = true)
#  |    |-- redirected: boolean (nullable = true)
#  |    |-- type: long (nullable = true)
#  |-- requisition: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- salary: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- from: long (nullable = true)
#  |    |-- performanceCompensation: long (nullable = true)
#  |    |-- show: boolean (nullable = true)
#  |    |-- time: long (nullable = true)
#  |    |-- to: long (nullable = true)
#  |    |-- variableCompensation: long (nullable = true)
#  |-- scraped_at: string (nullable = true)
#  |-- scraped_by_uuid: string (nullable = true)
#  |-- scraped_crawler: string (nullable = true)
#  |-- scraped_identifier: string (nullable = true)
#  |-- scraped_record_version: string (nullable = true)
#  |-- scraped_url: string (nullable = true)
#  |-- scraped_uuid: string (nullable = true)
#  |-- simVal: string (nullable = true)
#  |-- skill: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- hasSkills: boolean (nullable = true)
#  |    |-- skills: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- __ref: string (nullable = true)
#  |-- subcategory: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- tags: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- lessThan20: boolean (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- workMode: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- url: string (nullable = true)
# (142015, None)

# %%
#df.toPandas()
df.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Job:value              | Job:17038265
#  __typename             | Job
#  applied                | false
#  autoinclusion          | {JobAutoinclusion, false, }
#  bullets                | []
#  category               | {JobCategory:4}
#  company                | {JobCompany, false, https://cdn-h4.occ.com.mx/images/logos/300x300/66/66632d1208b54ee6a1955d23a527239e.jpg, Bufete Mexicano de Aduanas, Bufete-Mexicano-de-Aduanas, {CompanyProfile:518491}, null, empleos/bolsa-de-trabajo-Bufete-Mexicano-de-Aduanas/}
#  contact                | {JobContact, , , , false}
#  dates                  | {JobDates, 2023-07-13 10:10:06, 2023-09-11 23:59:59, 2023-07-13 00:00:00}
#  description            | Descripción del empleo  Edad: 22 años en adelante  Sexo: Indistinto  Estado Civil: Indistinto  Experiencia en: Manejo portal bancario, Conciliaciones Bancarias  Pago a Proveedores   Manejo de TRANSFER ...
#  education              | {JobEducation, ACADEMIC_WITH_DEGREE, empleos/}
#  friendlyId             | 17038265-auxiliar-de-tesoreria
#  googleForJobs          | {GoogleForJobs, true, true}
#  hiring                 | {JobHiring, false, true, false, true, false, empleos/permanente/}
#  id                     | 17038265
#  jobBody                | <p>Descripci&oacute;n del empleo</p><p>Edad: 22 a&ntilde;os en adelante</p><p>Sexo: Indistinto</p><p>Estado Civil: Indistinto</p><p>Experiencia en: Manejo portal bancario, Conciliaciones Bancarias</p><p>Pago a Proveedores </p><p>Manejo de TRANSFERENCIAS ELECTR&Oacute;NICAS.</p><p>Tipo de puesto: Tiempo completo</p>
#  jobType                | STANDOUT
#  level                  | {JobLevel:}
#  location               | {JobLocation, Matamoros, Tamaulipas, [{JobLocationData, {CityLocation, Matamoros, Matamoros, null, empleos/en-tamaulipas/en-la-ciudad-de-matamoros/}, {CountryLocation:MX}, 305, 126386, {StateLocation, Tamps., Tamaulipas, null, empleos/en-tamaulipas/}, {ZoneLocation, }}], empleos-en-tamaulipas}
#  profileId              | 518491
#  redirect               | {JobRedirect, , false, false, 0}
#  requisition            | {JobRequisition:}
#  salary                 | {JobSalary, 0, 0, false, 0, 0, 0}
#  scraped_at             | 2023-07-14 12:43:30.764101
#  scraped_by_uuid        | 077074cbaa7d4bff9e81107cf89d9b76
#  scraped_crawler        | SneakySpider
#  scraped_identifier     | 17038265
#  scraped_record_version | 0.0.10
#  scraped_url            | https://www.occ.com.mx/empleo/oferta/17038265-auxiliar-de-tesoreria/
#  scraped_uuid           | c09be115-1fc1-4493-9ceb-0444fbd1f977
#  simVal                 | null
#  skill                  | {JobSkills, false, []}
#  subcategory            | {JobSubcategory:88}
#  tags                   | {JobTags, false}
#  title                  | Auxiliar de tesorería
#  url                    | /empleo/oferta/17038265-auxiliar-de-tesoreria?rank=1&page=1&sessionid=&userid=&uuid=cd0c3da5-e978-4e9a-9166-f4704b6a79d6&origin=unknown&type=1&ai=false&ais=&showseo=true&returnURL=%2Fempleos-en-mexico-y-el-mundo%3Fsessionid%3D%26userid%3D%231
#  workMode               | {JobWorkMode, IN_PERSON, empleos/tipo-en-oficina/}
# only showing top 1 row

# %%
df.count(), df.select('id').distinct().count()
# Out:
# (142015, 139142)

# %%
df.groupby("redirect.type").count().show()
# Out:
# +----+-----+
# |type|count|
# +----+-----+
# |   0|81815|
# |   1| 4046|
# |   2|56154|
# +----+-----+

# %%
df.groupby("jobType").count().show()
# Out:
# +--------+------+
# | jobType| count|
# +--------+------+
# | PREMIUM|  3180|
# |STANDOUT| 30031|
# | CLASSIC|108804|
# +--------+------+

# %%
df.groupby("jobType").pivot("redirect.type").count().show()
# Out:
# +--------+-----+----+-----+
# | jobType|    0|   1|    2|
# +--------+-----+----+-----+
# | PREMIUM| 3157|  23| null|
# |STANDOUT|29457| 350|  224|
# | CLASSIC|49201|3673|55930|
# +--------+-----+----+-----+

# %%
pdf = df.groupby("jobType").pivot("redirect.type").count().toPandas().fillna(0).set_index('jobType')
pdf.columns = ['NoRedir', 'Redir1', 'Redir2']
pdf.div(pdf.sum(axis=1), axis=0)
# Out:
#            NoRedir    Redir1    Redir2
# jobType
# PREMIUM   0.992767  0.007233  0.000000
# STANDOUT  0.980886  0.011655  0.007459
# CLASSIC   0.452198  0.033758  0.514044

# %%
pdf.div(pdf.sum(axis=0), axis=1)
# Out:
#            NoRedir    Redir1    Redir2
# jobType
# PREMIUM   0.038587  0.005685  0.000000
# STANDOUT  0.360044  0.086505  0.003989
# CLASSIC   0.601369  0.907810  0.996011

# %%
pdf.div(pdf.sum(axis=None))
# Out:
#            NoRedir    Redir1    Redir2
# jobType
# PREMIUM   0.038587  0.005685  0.000000
# STANDOUT  0.360044  0.086505  0.003989
# CLASSIC   0.601369  0.907810  0.996011

# %%
cat_count = df.groupby("category").count().orderBy(F.col("count").desc())
split_col = F.split(cat_count["category.__ref"].cast("String"), ":")
cat_count = cat_count.withColumn("category_id", split_col.getItem(1).cast("INT"))
cat_count = cat_count.join(categories.select("id", "description"), cat_count.category_id == categories.id, how="inner")
cat_count = cat_count.select(["category_id", "description", "count"]).orderBy(F.col("count").desc())

# %%
sum = cat_count.select(F.sum("count")).collect()[0][0]
cat_count = cat_count.withColumn("percentage", F.col("count") / sum)
cat_count.show(cat_count.count(), truncate=False)
# Out:
# +-----------+------------------------------------------------+-----+---------------------+
# |category_id|description                                     |count|percentage           |
# +-----------+------------------------------------------------+-----+---------------------+
# |19         |Ventas                                          |30356|0.21375206844347427  |
# |1          |Administrativo                                  |17105|0.12044502341301976  |
# |17         |Tecnologías de la Información - Sistemas        |15401|0.10844629088476569  |
# |4          |Contabilidad - Finanzas                         |14145|0.09960215470196811  |
# |10         |Logística - Transporte - Distribución - Almacén |11732|0.0826109917966412   |
# |11         |Manufactura - Producción - Operación            |10718|0.07547090096116607  |
# |9          |Ingeniería                                      |8323 |0.05860648523043341  |
# |21         |Atención a clientes - Call Center               |7146 |0.0503186283139105   |
# |13         |Recursos humanos                                |5644 |0.039742280744991726 |
# |23         |Servicios generales - Oficios - Seguridad       |4146 |0.02919409921487167  |
# |5          |Construcción - Inmobiliaria - Arquitectura      |3086 |0.02173009893321128  |
# |15         |Sector salud                                    |2949 |0.020765412104355174 |
# |12         |Mercadotecnia - Publicidad - Relaciones Públicas|2931 |0.02063866492976094  |
# |18         |Turismo - Hospitalidad - Gastronomía            |2385 |0.016794000633735873 |
# |16         |Seguros y reaseguros                            |1462 |0.010294687180931591 |
# |8          |Educación                                       |1405 |0.009893321128049854 |
# |7          |Derecho y leyes                                 |1012 |0.007126007816075767 |
# |6          |Arte y diseño                                   |813  |0.005724747385839524 |
# |3          |Comunicación y creatividad                      |527  |0.003710875611731155 |
# |2          |Minería - Energía - Recursos Naturales          |242  |0.0017040453473224659|
# |20         |Veterinaria - Agricultura                       |195  |0.0013730943914375242|
# |14         |Deportes - Salud - Belleza                      |170  |0.001197056648945534 |
# |22         |Ciencias sociales - Humanidades                 |87   |6.126113438721262E-4 |
# |0          |                                                |35   |2.464528394887864E-4 |
# +-----------+------------------------------------------------+-----+---------------------+

# %%
split_col = F.split(df["category.__ref"].cast("String"), ":")
cat_count_redir = df.withColumn("category_id", split_col.getItem(1).cast("INT"))
cat_count_redir = cat_count_redir.groupby("category_id").pivot("redirect.type").count()
cat_count_redir = cat_count_redir.join(categories.select("id", "description"), cat_count_redir.category_id == categories.id, how="inner")
cat_count_redir = cat_count_redir.select(["description", "0", "1", "2"]).sort(F.col("0").desc()).toPandas().fillna(0)
cat_count_redir.columns = ["Category", "NoRedir", "Redir1", "Redir2(AGG)"]
cat_count_redir = cat_count_redir.set_index("Category")
cat_count_redir = cat_count_redir.div(cat_count_redir.sum(axis=1), axis=0)
cat_count_redir
# Out:
#                                                    NoRedir    Redir1  \
# Category
# Ventas                                            0.569146  0.038081
# Contabilidad - Finanzas                           0.672605  0.026935
# Tecnologías de la Información - Sistemas          0.546393  0.037335
# Administrativo                                    0.408769  0.023736
# Logística - Transporte - Distribución - Almacén   0.591885  0.012359
# Manufactura - Producción - Operación              0.543665  0.018567
# Ingeniería                                        0.640514  0.026433
# Recursos humanos                                  0.749468  0.027640
# Atención a clientes - Call Center                 0.453820  0.023510
# Construcción - Inmobiliaria - Arquitectura        0.826960  0.014906
# Sector salud                                      0.782977  0.015259
# Mercadotecnia - Publicidad - Relaciones Públicas  0.693279  0.016718
# Servicios generales - Oficios - Seguridad         0.353835  0.042209
# Turismo - Hospitalidad - Gastronomía              0.485954  0.010482
# Seguros y reaseguros                              0.750342  0.167579
# Educación                                         0.732384  0.004982
# Derecho y leyes                                   0.817194  0.027668
# Arte y diseño                                     0.773678  0.003690
# Comunicación y creatividad                        0.753321  0.009488
# Minería - Energía - Recursos Naturales            0.871901  0.020661
# Veterinaria - Agricultura                         0.779487  0.020513
# Deportes - Salud - Belleza                        0.641176  0.005882
# Ciencias sociales - Humanidades                   0.827586  0.022989
#                                                   0.000000  0.000000
#
#                                                   Redir2(AGG)
# Category
# Ventas                                               0.392772
# Contabilidad - Finanzas                              0.300460
# Tecnologías de la Información - Sistemas             0.416272
# Administrativo                                       0.567495
# Logística - Transporte - Distribución - Almacén      0.395755
# Manufactura - Producción - Operación                 0.437768
# Ingeniería                                           0.333053
# Recursos humanos                                     0.222892
# Atención a clientes - Call Center                    0.522670
# Construcción - Inmobiliaria - Arquitectura           0.158134
# Sector salud                                         0.201763
# Mercadotecnia - Publicidad - Relaciones Públicas     0.290003
# Servicios generales - Oficios - Seguridad            0.603956
# Turismo - Hospitalidad - Gastronomía                 0.503564
# Seguros y reaseguros                                 0.082079
# Educación                                            0.262633
# Derecho y leyes                                      0.155138
# Arte y diseño                                        0.222632
# Comunicación y creatividad                           0.237192
# Minería - Energía - Recursos Naturales               0.107438
# Veterinaria - Agricultura                            0.200000
# Deportes - Salud - Belleza                           0.352941
# Ciencias sociales - Humanidades                      0.149425
#                                                      1.000000

# %%
cat_count_redir.sort_values("Redir2(AGG)", ascending=False)
# Out:
#                                                    NoRedir    Redir1  \
# Category
#                                                   0.000000  0.000000
# Servicios generales - Oficios - Seguridad         0.353835  0.042209
# Administrativo                                    0.408769  0.023736
# Atención a clientes - Call Center                 0.453820  0.023510
# Turismo - Hospitalidad - Gastronomía              0.485954  0.010482
# Manufactura - Producción - Operación              0.543665  0.018567
# Tecnologías de la Información - Sistemas          0.546393  0.037335
# Logística - Transporte - Distribución - Almacén   0.591885  0.012359
# Ventas                                            0.569146  0.038081
# Deportes - Salud - Belleza                        0.641176  0.005882
# Ingeniería                                        0.640514  0.026433
# Contabilidad - Finanzas                           0.672605  0.026935
# Mercadotecnia - Publicidad - Relaciones Públicas  0.693279  0.016718
# Educación                                         0.732384  0.004982
# Comunicación y creatividad                        0.753321  0.009488
# Recursos humanos                                  0.749468  0.027640
# Arte y diseño                                     0.773678  0.003690
# Sector salud                                      0.782977  0.015259
# Veterinaria - Agricultura                         0.779487  0.020513
# Construcción - Inmobiliaria - Arquitectura        0.826960  0.014906
# Derecho y leyes                                   0.817194  0.027668
# Ciencias sociales - Humanidades                   0.827586  0.022989
# Minería - Energía - Recursos Naturales            0.871901  0.020661
# Seguros y reaseguros                              0.750342  0.167579
#
#                                                   Redir2(AGG)
# Category
#                                                      1.000000
# Servicios generales - Oficios - Seguridad            0.603956
# Administrativo                                       0.567495
# Atención a clientes - Call Center                    0.522670
# Turismo - Hospitalidad - Gastronomía                 0.503564
# Manufactura - Producción - Operación                 0.437768
# Tecnologías de la Información - Sistemas             0.416272
# Logística - Transporte - Distribución - Almacén      0.395755
# Ventas                                               0.392772
# Deportes - Salud - Belleza                           0.352941
# Ingeniería                                           0.333053
# Contabilidad - Finanzas                              0.300460
# Mercadotecnia - Publicidad - Relaciones Públicas     0.290003
# Educación                                            0.262633
# Comunicación y creatividad                           0.237192
# Recursos humanos                                     0.222892
# Arte y diseño                                        0.222632
# Sector salud                                         0.201763
# Veterinaria - Agricultura                            0.200000
# Construcción - Inmobiliaria - Arquitectura           0.158134
# Derecho y leyes                                      0.155138
# Ciencias sociales - Humanidades                      0.149425
# Minería - Energía - Recursos Naturales               0.107438
# Seguros y reaseguros                                 0.082079

# %%
subcat_count = df.groupby("subcategory").count().orderBy(F.col("count").desc())
split_col = F.split(subcat_count["subcategory.__ref"].cast("String"), ":")
subcat_count = subcat_count.withColumn("subcategory_id", split_col.getItem(1).cast("INT"))
subcat_count = subcat_count.join(subcategories.select("id", "description"), subcat_count.subcategory_id == subcategories.id, how="inner")
subcat_count.orderBy(F.col("count").desc()).show(25)
# Out:
# +--------------------+-----+--------------+---+--------------------+
# |         subcategory|count|subcategory_id| id|         description|
# +--------------------+-----+--------------+---+--------------------+
# | {JobSubcategory:29}|10060|            29| 29|      Administración|
# |{JobSubcategory:319}| 6311|           319|319|   Ventas en general|
# |{JobSubcategory:260}| 5994|           260|260| Atención al cliente|
# |{JobSubcategory:149}| 4135|           149|149|Almacén - Inventario|
# |{JobSubcategory:242}| 3961|           242|242|Desarrollo de sof...|
# |{JobSubcategory:275}| 3575|           275|275|Administración de...|
# | {JobSubcategory:78}| 3271|            78| 78|        Contabilidad|
# |{JobSubcategory:286}| 3198|           286|286|     Ventas de campo|
# | {JobSubcategory:25}| 3132|            25| 25|  Crédito y cobranza|
# |{JobSubcategory:190}| 2187|           190|190|Reclutamiento y s...|
# | {JobSubcategory:30}| 1929|            30| 30|  Control de Calidad|
# |{JobSubcategory:424}| 1907|           424|424|              Cajero|
# |  {JobSubcategory:2}| 1803|             2|  2|Auxiliar administ...|
# |{JobSubcategory:237}| 1719|           237|237|Administración de...|
# |{JobSubcategory:304}| 1717|           304|304|Mantenimiento gen...|
# |{JobSubcategory:251}| 1716|           251|251|     Soporte técnico|
# |{JobSubcategory:192}| 1681|           192|192|           Seguridad|
# |{JobSubcategory:285}| 1637|           285|285| Ventas corporativas|
# |{JobSubcategory:287}| 1573|           287|287|Venta al detalle ...|
# |{JobSubcategory:150}| 1526|           150|150|              Chofer|
# | {JobSubcategory:15}| 1510|            15| 15|             Compras|
# |{JobSubcategory:289}| 1494|           289|289|Promotor - Demost...|
# | {JobSubcategory:18}| 1494|            18| 18|Ingeniería indust...|
# |{JobSubcategory:307}| 1426|           307|307|         Manufactura|
# | {JobSubcategory:75}| 1381|            75| 75|   Auxiliar contable|
# +--------------------+-----+--------------+---+--------------------+
# only showing top 25 rows

# %%
split_col = F.split(df["subcategory.__ref"].cast("String"), ":")
subcat_count_redir = df.withColumn("subcategory_id", split_col.getItem(1).cast("INT"))
subcat_count_redir = subcat_count_redir.groupby("subcategory_id").pivot("redirect.type").count()
subcat_count_redir = subcat_count_redir.join(subcategories.select("id", "description"), subcat_count_redir.subcategory_id == subcategories.id, how="inner")
subcat_count_redir = subcat_count_redir.select(["description", "0", "1", "2"]).sort(F.col("0").desc()).toPandas().fillna(0)
subcat_count_redir.columns = ["subcategory", "NoRedir", "Redir1", "Redir2(AGG)"]
subcat_count_redir = subcat_count_redir.set_index("subcategory")
subcat_count_redir = subcat_count_redir.div(subcat_count_redir.sum(axis=1), axis=0)
pd.set_option('display.max_rows', None)
subcat_count_redir
# Out:
#                                                NoRedir    Redir1  Redir2(AGG)
# subcategory
# Ventas en general                             0.587546  0.032008     0.380447
# Contabilidad                                  0.803118  0.008254     0.188627
# Administración de ventas                      0.653427  0.033566     0.313007
# Administración                                0.220378  0.026143     0.753479
# Atención al cliente                           0.364031  0.021522     0.614448
# Ventas de campo                               0.655410  0.040650     0.303940
# Almacén - Inventario                          0.441354  0.014268     0.544377
# Reclutamiento y selección de personal         0.798811  0.018747     0.182442
# Desarrollo de software - Programador          0.422368  0.066145     0.511487
# Crédito y cobranza                            0.445402  0.017880     0.536718
# Administración de proyectos                   0.706806  0.036649     0.256545
# Ventas corporativas                           0.733048  0.033598     0.233354
# Auxiliar administrativo                       0.631725  0.013311     0.354964
# Logística                                     0.837435  0.017151     0.145414
# Administración de personal                    0.960073  0.013612     0.026316
# Representante de ventas                       0.779389  0.022901     0.197710
# Abastecimiento                                0.818704  0.016407     0.164889
# Auxiliar contable                             0.713975  0.004345     0.281680
# Comercial                                     0.754440  0.039382     0.206178
# Soporte técnico                               0.567599  0.017483     0.414918
# Manufactura                                   0.638850  0.026648     0.334502
# Venta al detalle - Retail                     0.571519  0.069294     0.359186
# Administración de oficina                     0.867961  0.022330     0.109709
# Administración de operaciones                 0.770331  0.015192     0.214477
# Compras                                       0.563576  0.013245     0.423179
# Call center                                   0.924779  0.034292     0.040929
# Comercio Exterior - Importación -Exportación  0.752941  0.003620     0.243439
# Control de Calidad                            0.428720  0.018663     0.552618
# Ingeniero                                     0.760930  0.026977     0.212093
# Mantenimiento general                         0.463017  0.012813     0.524170
# Ingeniería industrial                         0.513387  0.030790     0.455823
# Mercadotecnia                                 0.612328  0.017843     0.369830
# Ventas de piso                                0.682331  0.010338     0.307331
# Ventas por teléfono - Telemarketing           0.684261  0.014395     0.301344
# Operaciones                                   0.486322  0.020517     0.493161
# Administración de obra                        0.848202  0.017310     0.134487
# Seguridad                                     0.376562  0.012493     0.610946
# Automatización                                0.792929  0.039141     0.167929
# Asesoría comercial                            0.577841  0.034384     0.387775
# Finanzas                                      0.762551  0.085482     0.151967
# Ventas Técnicas                               0.645199  0.039813     0.314988
# Medicina general                              0.797376  0.007289     0.195335
# Redes - Telecomunicaciones                    0.600892  0.015608     0.383501
# Chofer                                        0.351900  0.002621     0.645478
# Desarrollo de negocios                        0.479414  0.043916     0.476670
# Maestro - Docente - Profesor                  0.668798  0.006394     0.324808
# Auditoría                                     0.722222  0.020833     0.256944
# Farmacéutica                                  0.717143  0.034286     0.248571
# Consultoría TI                                0.592920  0.011378     0.395702
# Construcción                                  0.939638  0.018109     0.042254
# Impuestos                                     0.699849  0.016591     0.283560
# Servicios generales                           0.567127  0.081556     0.351317
# Embarque y distribución                       0.654919  0.020558     0.324523
# Servicio                                      0.884462  0.015936     0.099602
# Base de datos                                 0.633284  0.026510     0.340206
# Actuaría                                      0.904459  0.046709     0.048832
# Ingeniería civil                              0.811069  0.013359     0.175573
# Banca                                         0.741652  0.112478     0.145870
# Informática                                   0.633846  0.033846     0.332308
# Promotor - Demostradoras                      0.265730  0.036145     0.698126
# Control de producción                         0.473684  0.015550     0.510766
# Seguridad informática                         0.547091  0.047091     0.405817
# Recepción y operación                         0.694346  0.010601     0.295053
# Capacitación y desarrollo                     0.600306  0.030628     0.369066
# Mantenimiento mecánico                        0.584112  0.012461     0.403427
# Ingeniería mecánica                           0.700576  0.040307     0.259117
# Distribución                                  0.790850  0.019608     0.189542
# Ingeniería automotriz                         0.610922  0.032423     0.356655
# Administrador de sistemas                     0.531348  0.034483     0.434169
# Marketing digital                             0.843434  0.010101     0.146465
# Desarrollo web                                0.606618  0.009191     0.384191
# SAP                                           0.577933  0.015762     0.406305
# Ingeniería de mantenimiento                   0.569912  0.014159     0.415929
# Nómina                                        0.886111  0.008333     0.105556
# Ventas de seguros - Reaseguros                0.703125  0.149554     0.147321
# Cuentas por pagar                             0.665245  0.027719     0.307036
# Enfermería                                    0.747549  0.014706     0.237745
# Ventas de mayoreo                             0.533217  0.008741     0.458042
# Ingeniería de procesos                        0.711584  0.026005     0.262411
# Tráfico                                       0.675862  0.004598     0.319540
# Arquitecto                                    0.741772  0.010127     0.248101
# Ingeniería electromecánica                    0.627155  0.010776     0.362069
# Pruebas - Control de calidad                  0.443910  0.032051     0.524038
# Ingeniería eléctrica                          0.545455  0.015810     0.438735
# Diseño gráfico                                0.678218  0.000000     0.321782
# Restaurante - Bar                             0.464471  0.008666     0.526863
# Infraestructura                               0.648649  0.029484     0.321867
# Instalaciones e infraestructura               0.893993  0.021201     0.084806
# E-Commerce                                    0.900369  0.011070     0.088561
# Ayudante general                              0.189953  0.017268     0.792779
# Administración de proyectos                   0.762987  0.038961     0.198052
# Derecho                                       0.781879  0.040268     0.177852
# Contabilidad de costos - Inventario           0.623229  0.025496     0.351275
# Facturación                                   0.700000  0.012903     0.287097
# Beneficios y compensaciones                   0.476718  0.017738     0.505543
# Ventas inmobiliarias                          0.522277  0.019802     0.457921
# Planeación estratégica                        0.537234  0.026596     0.436170
# Derecho corporativo                           0.781250  0.023438     0.195312
# Especialidades médicas                        0.956522  0.000000     0.043478
# Ingeniería química                            0.702509  0.017921     0.279570
# Cajero                                        0.102779  0.061353     0.835868
# Finanzas corporativas                         0.754864  0.046693     0.198444
# Ejecutivo empresarial banca                   0.362069  0.136015     0.501916
# Dirección académica                           0.814655  0.000000     0.185345
# Tesorería                                     0.737255  0.023529     0.239216
# Ingeniería electrónica                        0.628763  0.020067     0.351171
# Análisis financiero - Pronóstico              0.481579  0.063158     0.455263
# Ventas por cambaceo                           0.520000  0.054286     0.425714
# Investigación de mercado                      0.721116  0.015936     0.262948
# Agente de seguros                             0.947368  0.042105     0.010526
# Hoteles                                       0.459318  0.000000     0.540682
# Relaciones laborales                          0.770270  0.022523     0.207207
# Mantenimiento eléctrico                       0.814634  0.019512     0.165854
# Mantenimiento general                         0.976331  0.011834     0.011834
# Obra                                          0.841026  0.000000     0.158974
# Apoyo a ventas                                0.735160  0.059361     0.205479
# Técnico                                       0.859459  0.016216     0.124324
# Contraloría                                   0.585185  0.062963     0.351852
# Gestión de seguros                            0.840426  0.154255     0.005319
# Cocina                                        0.290741  0.012963     0.696296
# Medicina laboral                              0.957317  0.024390     0.018293
# Desarrollo organizacional                     0.875000  0.000000     0.125000
# Seguridad e higiene                           0.684932  0.004566     0.310502
# Ingeniería de datos                           0.668182  0.027273     0.304545
# Siniestros                                    0.604938  0.316872     0.078189
# Procesamiento de datos                        0.304622  0.056723     0.638655
# Analista de ventas                            0.401114  0.044568     0.554318
# Residente de obra                             0.910256  0.000000     0.089744
# Agencia de viajes                             0.848485  0.036364     0.115152
# Laboratorio - Patología                       0.592105  0.008772     0.399123
# Asistente de dirección                        0.848101  0.056962     0.094937
# Ambulancia - Paramédicos                      0.852564  0.006410     0.141026
# Alimentos y bebidas                           0.809816  0.030675     0.159509
# Comunicación e imagen                         0.760234  0.017544     0.222222
# Control de materiales                         0.434783  0.010033     0.555184
# Asesor financiero                             0.563877  0.030837     0.405286
# Mantenimiento automotríz                      0.833333  0.000000     0.166667
# Soporte                                       0.924812  0.030075     0.045113
# Secretaria                                    0.506276  0.008368     0.485356
# Desarrollo de aplicaciones móviles            0.645161  0.021505     0.333333
# Actuario                                      0.791946  0.167785     0.040268
# Aduana                                        0.466135  0.007968     0.525896
# Relaciones públicas                           0.774834  0.026490     0.198675
# Arquitecto de soluciones                      0.633333  0.038889     0.327778
# Diseñador industrial                          0.865079  0.015873     0.119048
# Idiomas                                       0.670807  0.006211     0.322981
# Mensajería                                    0.519231  0.009615     0.471154
# Mantenimiento electrónico                     0.435685  0.004149     0.560166
# Producto                                      0.673077  0.070513     0.256410
# Gestión de flotas                             0.762963  0.014815     0.222222
# Turismo                                       0.710345  0.000000     0.289655
# Post venta                                    0.886957  0.034783     0.078261
# Derecho mercantil                             0.821138  0.040650     0.138211
# Ingeniería en alimentos                       0.884956  0.035398     0.079646
# Innovación y desarrollo de productos          0.614907  0.031056     0.354037
# Agronomía y granja                            0.796748  0.032520     0.170732
# Inyección de plásticos                        0.590062  0.006211     0.403727
# Administración de riesgo                      0.606452  0.045161     0.348387
# Derecho laboral                               0.938144  0.000000     0.061856
# Otros oficios                                 0.323843  0.441281     0.234875
# Diseño de interiores                          0.567742  0.038710     0.393548
# Ingeniería de planta                          0.517857  0.130952     0.351190
# Servicios estudiantiles                       0.965909  0.000000     0.034091
# Planeación financiera                         0.508982  0.089820     0.401198
# Diseño web - Digital                          0.933333  0.022222     0.044444
# Máquinas y herramientas                       0.414141  0.020202     0.565657
# Jefe de piso                                  0.675000  0.016667     0.308333
# Publicidad                                    0.740741  0.000000     0.259259
# Radiología                                    1.000000  0.000000     0.000000
# Petróleo y energía                            0.963415  0.000000     0.036585
# Odontología y especialidades                  0.759615  0.019231     0.221154
# Big data                                      0.847826  0.000000     0.152174
# Organización de eventos                       0.750000  0.000000     0.250000
# Archivista y manejo de documentación          0.685185  0.037037     0.277778
# Científico de datos                           0.959459  0.000000     0.040541
# Mercados financieros - Inversión              0.460526  0.098684     0.440789
# Diseño mecánico                               0.546875  0.039062     0.414062
# Ingeniería ambiental                          0.784091  0.011364     0.204545
# Chef                                          0.561983  0.000000     0.438017
# Limpieza                                      0.207430  0.000000     0.792570
# Derecho inmobiliario                          0.916667  0.013889     0.069444
# Suscripción - Seguros                         0.706522  0.141304     0.152174
# E- Business                                   0.406667  0.040000     0.553333
# Creatividad y diseño                          1.000000  0.000000     0.000000
# Administración de seguros y fianzas           0.923077  0.030769     0.046154
# Valuador - Joyero                             0.233871  0.000000     0.766129
# Instructor - Capacitador                      0.983051  0.000000     0.016949
# Animación digital                             0.950000  0.000000     0.050000
# Transporte aéreo                              0.903226  0.016129     0.080645
# Planeación de medios                          0.482456  0.000000     0.517544
# Moda y diseño textil                          0.782609  0.000000     0.217391
# Operador de CNC                               0.569892  0.000000     0.430108
# Producción audiovisual y digital              0.604651  0.000000     0.395349
# Eventos - Banquetes - Convenciones            0.866667  0.000000     0.133333
# Economía                                      0.796875  0.078125     0.125000
# Capturista                                    0.844828  0.017241     0.137931
# Innovación y desarrollo                       0.545455  0.056818     0.397727
# Médico veterinario                            0.738462  0.000000     0.261538
# Edición de contenido                          0.671429  0.000000     0.328571
# Operador de tractocamión                      0.671429  0.014286     0.314286
# Diseño de producto                            0.940000  0.000000     0.060000
# Soporte de ventas                             0.271676  0.011561     0.716763
# Montacargas                                   0.959184  0.040816     0.000000
# Medios de comunicación                        0.978723  0.000000     0.021277
# Administración de inmuebles y activos fijos   0.647887  0.014085     0.338028
# Urbanismo                                     0.494253  0.011494     0.494253
# Consultoría                                   0.732143  0.035714     0.232143
# Optometrista                                  0.754717  0.000000     0.245283
# Psicopedagogía                                0.764706  0.000000     0.235294
# Psicología                                    0.780000  0.020000     0.200000
# Spa                                           0.600000  0.000000     0.400000
# Ingeniero agrónomo                            0.812500  0.041667     0.145833
# Criminalística                                0.948718  0.025641     0.025641
# Entrenador personal                           0.711538  0.019231     0.269231
# Robótica- Mecatrónica - Nanotecnología        0.837209  0.000000     0.162791
# Corredor de seguros y reaseguros              0.972222  0.000000     0.027778
# Transporte ferroviario y marítimo             0.829268  0.000000     0.170732
# Artes gráficas                                0.850000  0.000000     0.150000
# Social media                                  0.523077  0.015385     0.461538
# Nutrición                                     0.647059  0.000000     0.352941
# Producción audiovisual                        0.647059  0.000000     0.352941
# Terapeuta                                     0.868421  0.000000     0.131579
# Emisión seguros                               0.744186  0.162791     0.093023
# Derecho penal                                 0.857143  0.000000     0.142857
# Preventa                                      0.319149  0.085106     0.595745
# Maquinaria pesada - Operador                  0.909091  0.000000     0.090909
# Hojalatería y pintura                         0.371795  0.000000     0.628205
# UX - UI                                       0.935484  0.032258     0.032258
# Chofer ejecutivo                              0.965517  0.034483     0.000000
# Arte creativo                                 0.736842  0.000000     0.263158
# Ingeniería en aeronáutica - Aeroespacial      0.658537  0.097561     0.243902
# Asesor contable                               0.838710  0.032258     0.129032
# Chofer                                        0.928571  0.035714     0.035714
# Agronomía                                     1.000000  0.000000     0.000000
# Química                                       1.000000  0.000000     0.000000
# Fisioterapia y rehabilitación                 0.851852  0.000000     0.148148
# Derecho civil                                 0.956522  0.000000     0.043478
# Derecho fiscal                                0.628571  0.028571     0.342857
# Investigación clínica - Médica                0.954545  0.000000     0.045455
# Recepcionista                                 0.538462  0.000000     0.461538
# Periodismo                                    0.512195  0.000000     0.487805
# Ajustador                                     0.512821  0.435897     0.051282
# Colorista - Igualador                         0.909091  0.000000     0.090909
# Ingeniería en metalurgia                      0.625000  0.031250     0.343750
# Derecho notarial                              0.678571  0.071429     0.250000
# Camarista                                     0.118421  0.013158     0.868421
# Ingeniero en minas                            0.947368  0.000000     0.052632
# Capacitación en TI                            0.305085  0.000000     0.694915
# Estilismo                                     0.629630  0.000000     0.370370
# Auditoría Interna                             0.850000  0.100000     0.050000
# Consultoría ambiental                         0.739130  0.000000     0.260870
# Ingeniería en materiales                      0.404762  0.023810     0.571429
# Recursos naturales                            1.000000  0.000000     0.000000
# Ensamblador                                   0.888889  0.000000     0.111111
# Ingeniería textil                             0.405405  0.027027     0.567568
# Flebotomía                                    0.882353  0.058824     0.058824
# Cocina, bar y cafetería                       0.933333  0.066667     0.000000
# Educación especial                            1.000000  0.000000     0.000000
# Concierge                                     0.411765  0.000000     0.588235
# Operador de autobús                           0.933333  0.000000     0.066667
# Inteligencia artificial                       0.311111  0.111111     0.577778
# Educación física                              0.722222  0.055556     0.222222
# Metrología                                    0.684211  0.000000     0.315789
# Ingeniería en desarrollo sustentable          0.171053  0.000000     0.828947
# Entretenimiento                               1.000000  0.000000     0.000000
# Traducción                                    0.666667  0.000000     0.333333
# Editor                                        0.461538  0.076923     0.461538
# Dibujo técnico                                0.631579  0.000000     0.368421
# Coordinación de grupos                        0.550000  0.000000     0.450000
# Asesoría legal de seguros                     0.714286  0.000000     0.285714
# Desarrollo sustentable                        1.000000  0.000000     0.000000
# Capitán                                       0.714286  0.000000     0.285714
# Mensajero                                     1.000000  0.000000     0.000000
# Fotografía                                    0.666667  0.000000     0.333333
# Decoración                                    1.000000  0.000000     0.000000
# Otros                                         1.000000  0.000000     0.000000
# Laboratorista automotriz                      1.000000  0.000000     0.000000
# Lavandería                                    0.132075  0.000000     0.867925
# Trabajo social                                0.636364  0.090909     0.272727
# Diseño editorial                              1.000000  0.000000     0.000000
# Manicurista                                   0.500000  0.000000     0.500000
# Cinematografía                                1.000000  0.000000     0.000000
# Hostess                                       1.000000  0.000000     0.000000
# Técnico especialista en motores gas - Diesel  0.666667  0.000000     0.333333
# Petroquímica                                  1.000000  0.000000     0.000000
# Intérprete                                    1.000000  0.000000     0.000000
# Makeup artist                                 1.000000  0.000000     0.000000
# Humanidades                                   1.000000  0.000000     0.000000
# Sociología                                    1.000000  0.000000     0.000000
# Arte y cultura                                0.625000  0.000000     0.375000
# Geólogo                                       0.833333  0.000000     0.166667
# Operador de campo                             0.833333  0.000000     0.166667
# Guía de turismo                               0.666667  0.000000     0.333333
# Mesero                                        0.067797  0.000000     0.932203
# Ecología                                      1.000000  0.000000     0.000000
# Derecho minero y energético                   1.000000  0.000000     0.000000
# Medicina del deporte                          1.000000  0.000000     0.000000
# Estética canina                               0.750000  0.000000     0.250000
# Medicina alternativa                          1.000000  0.000000     0.000000
# Masajista                                     0.600000  0.000000     0.400000
# Música                                        0.333333  0.000000     0.666667
# Derecho ambiental                             1.000000  0.000000     0.000000
# Médico legista                                1.000000  0.000000     0.000000
# Biotecnología                                 0.142857  0.000000     0.857143
# Política                                      1.000000  0.000000     0.000000
# Supervisor de mina                            1.000000  0.000000     0.000000
# Investigación y desarrollo                    0.285714  0.571429     0.142857
# Riesgos                                       1.000000  0.000000     0.000000
# Ingeniería física                             1.000000  0.000000     0.000000
# Topografía                                    1.000000  0.000000     0.000000
# Biología                                      1.000000  0.000000     0.000000
# Taquillero                                    0.066667  0.133333     0.800000
# Seguridad ciudadana                           1.000000  0.000000     0.000000
# Letras                                        1.000000  0.000000     0.000000
# Lingüística                                   1.000000  0.000000     0.000000
# Viñedos                                       1.000000  0.000000     0.000000
# Matemáticas                                   1.000000  0.000000     0.000000
# Asistente médico                              1.000000  0.000000     0.000000
# Documentador                                  1.000000  0.000000     0.000000
# Operadores de maquinaria                      0.500000  0.500000     0.000000
# Pesca y acuicultura                           1.000000  0.000000     0.000000
# Ilustración                                   0.000000  0.000000     1.000000
# Plataformas                                   0.000000  0.000000     1.000000
# Ingeniería genética                           0.000000  0.000000     1.000000
# Pedicurista                                   0.000000  0.000000     1.000000
# Hipoteca                                      0.000000  0.000000     1.000000
#                                               0.000000  0.000000     1.000000

# %%
subcat_count_redir.sort_values("Redir2(AGG)", ascending=False)
# Out:
#                                                NoRedir    Redir1  Redir2(AGG)
# subcategory
#                                               0.000000  0.000000     1.000000
# Ilustración                                   0.000000  0.000000     1.000000
# Hipoteca                                      0.000000  0.000000     1.000000
# Pedicurista                                   0.000000  0.000000     1.000000
# Ingeniería genética                           0.000000  0.000000     1.000000
# Plataformas                                   0.000000  0.000000     1.000000
# Mesero                                        0.067797  0.000000     0.932203
# Camarista                                     0.118421  0.013158     0.868421
# Lavandería                                    0.132075  0.000000     0.867925
# Biotecnología                                 0.142857  0.000000     0.857143
# Cajero                                        0.102779  0.061353     0.835868
# Ingeniería en desarrollo sustentable          0.171053  0.000000     0.828947
# Taquillero                                    0.066667  0.133333     0.800000
# Ayudante general                              0.189953  0.017268     0.792779
# Limpieza                                      0.207430  0.000000     0.792570
# Valuador - Joyero                             0.233871  0.000000     0.766129
# Administración                                0.220378  0.026143     0.753479
# Soporte de ventas                             0.271676  0.011561     0.716763
# Promotor - Demostradoras                      0.265730  0.036145     0.698126
# Cocina                                        0.290741  0.012963     0.696296
# Capacitación en TI                            0.305085  0.000000     0.694915
# Música                                        0.333333  0.000000     0.666667
# Chofer                                        0.351900  0.002621     0.645478
# Procesamiento de datos                        0.304622  0.056723     0.638655
# Hojalatería y pintura                         0.371795  0.000000     0.628205
# Atención al cliente                           0.364031  0.021522     0.614448
# Seguridad                                     0.376562  0.012493     0.610946
# Preventa                                      0.319149  0.085106     0.595745
# Concierge                                     0.411765  0.000000     0.588235
# Inteligencia artificial                       0.311111  0.111111     0.577778
# Ingeniería en materiales                      0.404762  0.023810     0.571429
# Ingeniería textil                             0.405405  0.027027     0.567568
# Máquinas y herramientas                       0.414141  0.020202     0.565657
# Mantenimiento electrónico                     0.435685  0.004149     0.560166
# Control de materiales                         0.434783  0.010033     0.555184
# Analista de ventas                            0.401114  0.044568     0.554318
# E- Business                                   0.406667  0.040000     0.553333
# Control de Calidad                            0.428720  0.018663     0.552618
# Almacén - Inventario                          0.441354  0.014268     0.544377
# Hoteles                                       0.459318  0.000000     0.540682
# Crédito y cobranza                            0.445402  0.017880     0.536718
# Restaurante - Bar                             0.464471  0.008666     0.526863
# Aduana                                        0.466135  0.007968     0.525896
# Mantenimiento general                         0.463017  0.012813     0.524170
# Pruebas - Control de calidad                  0.443910  0.032051     0.524038
# Planeación de medios                          0.482456  0.000000     0.517544
# Desarrollo de software - Programador          0.422368  0.066145     0.511487
# Control de producción                         0.473684  0.015550     0.510766
# Beneficios y compensaciones                   0.476718  0.017738     0.505543
# Ejecutivo empresarial banca                   0.362069  0.136015     0.501916
# Manicurista                                   0.500000  0.000000     0.500000
# Urbanismo                                     0.494253  0.011494     0.494253
# Operaciones                                   0.486322  0.020517     0.493161
# Periodismo                                    0.512195  0.000000     0.487805
# Secretaria                                    0.506276  0.008368     0.485356
# Desarrollo de negocios                        0.479414  0.043916     0.476670
# Mensajería                                    0.519231  0.009615     0.471154
# Recepcionista                                 0.538462  0.000000     0.461538
# Social media                                  0.523077  0.015385     0.461538
# Editor                                        0.461538  0.076923     0.461538
# Ventas de mayoreo                             0.533217  0.008741     0.458042
# Ventas inmobiliarias                          0.522277  0.019802     0.457921
# Ingeniería industrial                         0.513387  0.030790     0.455823
# Análisis financiero - Pronóstico              0.481579  0.063158     0.455263
# Coordinación de grupos                        0.550000  0.000000     0.450000
# Mercados financieros - Inversión              0.460526  0.098684     0.440789
# Ingeniería eléctrica                          0.545455  0.015810     0.438735
# Chef                                          0.561983  0.000000     0.438017
# Planeación estratégica                        0.537234  0.026596     0.436170
# Administrador de sistemas                     0.531348  0.034483     0.434169
# Operador de CNC                               0.569892  0.000000     0.430108
# Ventas por cambaceo                           0.520000  0.054286     0.425714
# Compras                                       0.563576  0.013245     0.423179
# Ingeniería de mantenimiento                   0.569912  0.014159     0.415929
# Soporte técnico                               0.567599  0.017483     0.414918
# Diseño mecánico                               0.546875  0.039062     0.414062
# SAP                                           0.577933  0.015762     0.406305
# Seguridad informática                         0.547091  0.047091     0.405817
# Asesor financiero                             0.563877  0.030837     0.405286
# Inyección de plásticos                        0.590062  0.006211     0.403727
# Mantenimiento mecánico                        0.584112  0.012461     0.403427
# Planeación financiera                         0.508982  0.089820     0.401198
# Masajista                                     0.600000  0.000000     0.400000
# Spa                                           0.600000  0.000000     0.400000
# Laboratorio - Patología                       0.592105  0.008772     0.399123
# Innovación y desarrollo                       0.545455  0.056818     0.397727
# Consultoría TI                                0.592920  0.011378     0.395702
# Producción audiovisual y digital              0.604651  0.000000     0.395349
# Diseño de interiores                          0.567742  0.038710     0.393548
# Asesoría comercial                            0.577841  0.034384     0.387775
# Desarrollo web                                0.606618  0.009191     0.384191
# Redes - Telecomunicaciones                    0.600892  0.015608     0.383501
# Ventas en general                             0.587546  0.032008     0.380447
# Arte y cultura                                0.625000  0.000000     0.375000
# Estilismo                                     0.629630  0.000000     0.370370
# Mercadotecnia                                 0.612328  0.017843     0.369830
# Capacitación y desarrollo                     0.600306  0.030628     0.369066
# Dibujo técnico                                0.631579  0.000000     0.368421
# Ingeniería electromecánica                    0.627155  0.010776     0.362069
# Venta al detalle - Retail                     0.571519  0.069294     0.359186
# Ingeniería automotriz                         0.610922  0.032423     0.356655
# Auxiliar administrativo                       0.631725  0.013311     0.354964
# Innovación y desarrollo de productos          0.614907  0.031056     0.354037
# Nutrición                                     0.647059  0.000000     0.352941
# Producción audiovisual                        0.647059  0.000000     0.352941
# Contraloría                                   0.585185  0.062963     0.351852
# Servicios generales                           0.567127  0.081556     0.351317
# Contabilidad de costos - Inventario           0.623229  0.025496     0.351275
# Ingeniería de planta                          0.517857  0.130952     0.351190
# Ingeniería electrónica                        0.628763  0.020067     0.351171
# Administración de riesgo                      0.606452  0.045161     0.348387
# Ingeniería en metalurgia                      0.625000  0.031250     0.343750
# Derecho fiscal                                0.628571  0.028571     0.342857
# Base de datos                                 0.633284  0.026510     0.340206
# Administración de inmuebles y activos fijos   0.647887  0.014085     0.338028
# Manufactura                                   0.638850  0.026648     0.334502
# Fotografía                                    0.666667  0.000000     0.333333
# Desarrollo de aplicaciones móviles            0.645161  0.021505     0.333333
# Guía de turismo                               0.666667  0.000000     0.333333
# Traducción                                    0.666667  0.000000     0.333333
# Técnico especialista en motores gas - Diesel  0.666667  0.000000     0.333333
# Informática                                   0.633846  0.033846     0.332308
# Edición de contenido                          0.671429  0.000000     0.328571
# Arquitecto de soluciones                      0.633333  0.038889     0.327778
# Maestro - Docente - Profesor                  0.668798  0.006394     0.324808
# Embarque y distribución                       0.654919  0.020558     0.324523
# Idiomas                                       0.670807  0.006211     0.322981
# Infraestructura                               0.648649  0.029484     0.321867
# Diseño gráfico                                0.678218  0.000000     0.321782
# Tráfico                                       0.675862  0.004598     0.319540
# Metrología                                    0.684211  0.000000     0.315789
# Ventas Técnicas                               0.645199  0.039813     0.314988
# Operador de tractocamión                      0.671429  0.014286     0.314286
# Administración de ventas                      0.653427  0.033566     0.313007
# Seguridad e higiene                           0.684932  0.004566     0.310502
# Jefe de piso                                  0.675000  0.016667     0.308333
# Ventas de piso                                0.682331  0.010338     0.307331
# Cuentas por pagar                             0.665245  0.027719     0.307036
# Ingeniería de datos                           0.668182  0.027273     0.304545
# Ventas de campo                               0.655410  0.040650     0.303940
# Ventas por teléfono - Telemarketing           0.684261  0.014395     0.301344
# Recepción y operación                         0.694346  0.010601     0.295053
# Turismo                                       0.710345  0.000000     0.289655
# Facturación                                   0.700000  0.012903     0.287097
# Asesoría legal de seguros                     0.714286  0.000000     0.285714
# Capitán                                       0.714286  0.000000     0.285714
# Impuestos                                     0.699849  0.016591     0.283560
# Auxiliar contable                             0.713975  0.004345     0.281680
# Ingeniería química                            0.702509  0.017921     0.279570
# Archivista y manejo de documentación          0.685185  0.037037     0.277778
# Trabajo social                                0.636364  0.090909     0.272727
# Entrenador personal                           0.711538  0.019231     0.269231
# Arte creativo                                 0.736842  0.000000     0.263158
# Investigación de mercado                      0.721116  0.015936     0.262948
# Ingeniería de procesos                        0.711584  0.026005     0.262411
# Médico veterinario                            0.738462  0.000000     0.261538
# Consultoría ambiental                         0.739130  0.000000     0.260870
# Publicidad                                    0.740741  0.000000     0.259259
# Ingeniería mecánica                           0.700576  0.040307     0.259117
# Auditoría                                     0.722222  0.020833     0.256944
# Administración de proyectos                   0.706806  0.036649     0.256545
# Producto                                      0.673077  0.070513     0.256410
# Derecho notarial                              0.678571  0.071429     0.250000
# Organización de eventos                       0.750000  0.000000     0.250000
# Estética canina                               0.750000  0.000000     0.250000
# Farmacéutica                                  0.717143  0.034286     0.248571
# Arquitecto                                    0.741772  0.010127     0.248101
# Optometrista                                  0.754717  0.000000     0.245283
# Ingeniería en aeronáutica - Aeroespacial      0.658537  0.097561     0.243902
# Comercio Exterior - Importación -Exportación  0.752941  0.003620     0.243439
# Tesorería                                     0.737255  0.023529     0.239216
# Enfermería                                    0.747549  0.014706     0.237745
# Psicopedagogía                                0.764706  0.000000     0.235294
# Otros oficios                                 0.323843  0.441281     0.234875
# Ventas corporativas                           0.733048  0.033598     0.233354
# Consultoría                                   0.732143  0.035714     0.232143
# Educación física                              0.722222  0.055556     0.222222
# Comunicación e imagen                         0.760234  0.017544     0.222222
# Gestión de flotas                             0.762963  0.014815     0.222222
# Odontología y especialidades                  0.759615  0.019231     0.221154
# Moda y diseño textil                          0.782609  0.000000     0.217391
# Administración de operaciones                 0.770331  0.015192     0.214477
# Ingeniero                                     0.760930  0.026977     0.212093
# Relaciones laborales                          0.770270  0.022523     0.207207
# Comercial                                     0.754440  0.039382     0.206178
# Apoyo a ventas                                0.735160  0.059361     0.205479
# Ingeniería ambiental                          0.784091  0.011364     0.204545
# Psicología                                    0.780000  0.020000     0.200000
# Relaciones públicas                           0.774834  0.026490     0.198675
# Finanzas corporativas                         0.754864  0.046693     0.198444
# Administración de proyectos                   0.762987  0.038961     0.198052
# Representante de ventas                       0.779389  0.022901     0.197710
# Medicina general                              0.797376  0.007289     0.195335
# Derecho corporativo                           0.781250  0.023438     0.195312
# Distribución                                  0.790850  0.019608     0.189542
# Contabilidad                                  0.803118  0.008254     0.188627
# Dirección académica                           0.814655  0.000000     0.185345
# Reclutamiento y selección de personal         0.798811  0.018747     0.182442
# Derecho                                       0.781879  0.040268     0.177852
# Ingeniería civil                              0.811069  0.013359     0.175573
# Agronomía y granja                            0.796748  0.032520     0.170732
# Transporte ferroviario y marítimo             0.829268  0.000000     0.170732
# Automatización                                0.792929  0.039141     0.167929
# Mantenimiento automotríz                      0.833333  0.000000     0.166667
# Operador de campo                             0.833333  0.000000     0.166667
# Geólogo                                       0.833333  0.000000     0.166667
# Mantenimiento eléctrico                       0.814634  0.019512     0.165854
# Abastecimiento                                0.818704  0.016407     0.164889
# Robótica- Mecatrónica - Nanotecnología        0.837209  0.000000     0.162791
# Alimentos y bebidas                           0.809816  0.030675     0.159509
# Obra                                          0.841026  0.000000     0.158974
# Big data                                      0.847826  0.000000     0.152174
# Suscripción - Seguros                         0.706522  0.141304     0.152174
# Finanzas                                      0.762551  0.085482     0.151967
# Artes gráficas                                0.850000  0.000000     0.150000
# Fisioterapia y rehabilitación                 0.851852  0.000000     0.148148
# Ventas de seguros - Reaseguros                0.703125  0.149554     0.147321
# Marketing digital                             0.843434  0.010101     0.146465
# Banca                                         0.741652  0.112478     0.145870
# Ingeniero agrónomo                            0.812500  0.041667     0.145833
# Logística                                     0.837435  0.017151     0.145414
# Derecho penal                                 0.857143  0.000000     0.142857
# Investigación y desarrollo                    0.285714  0.571429     0.142857
# Ambulancia - Paramédicos                      0.852564  0.006410     0.141026
# Derecho mercantil                             0.821138  0.040650     0.138211
# Capturista                                    0.844828  0.017241     0.137931
# Administración de obra                        0.848202  0.017310     0.134487
# Eventos - Banquetes - Convenciones            0.866667  0.000000     0.133333
# Terapeuta                                     0.868421  0.000000     0.131579
# Asesor contable                               0.838710  0.032258     0.129032
# Desarrollo organizacional                     0.875000  0.000000     0.125000
# Economía                                      0.796875  0.078125     0.125000
# Técnico                                       0.859459  0.016216     0.124324
# Diseñador industrial                          0.865079  0.015873     0.119048
# Agencia de viajes                             0.848485  0.036364     0.115152
# Ensamblador                                   0.888889  0.000000     0.111111
# Administración de oficina                     0.867961  0.022330     0.109709
# Nómina                                        0.886111  0.008333     0.105556
# Servicio                                      0.884462  0.015936     0.099602
# Asistente de dirección                        0.848101  0.056962     0.094937
# Emisión seguros                               0.744186  0.162791     0.093023
# Colorista - Igualador                         0.909091  0.000000     0.090909
# Maquinaria pesada - Operador                  0.909091  0.000000     0.090909
# Residente de obra                             0.910256  0.000000     0.089744
# E-Commerce                                    0.900369  0.011070     0.088561
# Instalaciones e infraestructura               0.893993  0.021201     0.084806
# Transporte aéreo                              0.903226  0.016129     0.080645
# Ingeniería en alimentos                       0.884956  0.035398     0.079646
# Post venta                                    0.886957  0.034783     0.078261
# Siniestros                                    0.604938  0.316872     0.078189
# Derecho inmobiliario                          0.916667  0.013889     0.069444
# Operador de autobús                           0.933333  0.000000     0.066667
# Derecho laboral                               0.938144  0.000000     0.061856
# Diseño de producto                            0.940000  0.000000     0.060000
# Flebotomía                                    0.882353  0.058824     0.058824
# Ingeniero en minas                            0.947368  0.000000     0.052632
# Ajustador                                     0.512821  0.435897     0.051282
# Auditoría Interna                             0.850000  0.100000     0.050000
# Animación digital                             0.950000  0.000000     0.050000
# Actuaría                                      0.904459  0.046709     0.048832
# Administración de seguros y fianzas           0.923077  0.030769     0.046154
# Investigación clínica - Médica                0.954545  0.000000     0.045455
# Soporte                                       0.924812  0.030075     0.045113
# Diseño web - Digital                          0.933333  0.022222     0.044444
# Especialidades médicas                        0.956522  0.000000     0.043478
# Derecho civil                                 0.956522  0.000000     0.043478
# Construcción                                  0.939638  0.018109     0.042254
# Call center                                   0.924779  0.034292     0.040929
# Científico de datos                           0.959459  0.000000     0.040541
# Actuario                                      0.791946  0.167785     0.040268
# Petróleo y energía                            0.963415  0.000000     0.036585
# Chofer                                        0.928571  0.035714     0.035714
# Servicios estudiantiles                       0.965909  0.000000     0.034091
# UX - UI                                       0.935484  0.032258     0.032258
# Corredor de seguros y reaseguros              0.972222  0.000000     0.027778
# Administración de personal                    0.960073  0.013612     0.026316
# Criminalística                                0.948718  0.025641     0.025641
# Medios de comunicación                        0.978723  0.000000     0.021277
# Medicina laboral                              0.957317  0.024390     0.018293
# Instructor - Capacitador                      0.983051  0.000000     0.016949
# Mantenimiento general                         0.976331  0.011834     0.011834
# Agente de seguros                             0.947368  0.042105     0.010526
# Gestión de seguros                            0.840426  0.154255     0.005319
# Supervisor de mina                            1.000000  0.000000     0.000000
# Política                                      1.000000  0.000000     0.000000
# Riesgos                                       1.000000  0.000000     0.000000
# Ingeniería física                             1.000000  0.000000     0.000000
# Topografía                                    1.000000  0.000000     0.000000
# Biología                                      1.000000  0.000000     0.000000
# Entretenimiento                               1.000000  0.000000     0.000000
# Seguridad ciudadana                           1.000000  0.000000     0.000000
# Letras                                        1.000000  0.000000     0.000000
# Lingüística                                   1.000000  0.000000     0.000000
# Médico legista                                1.000000  0.000000     0.000000
# Matemáticas                                   1.000000  0.000000     0.000000
# Asistente médico                              1.000000  0.000000     0.000000
# Documentador                                  1.000000  0.000000     0.000000
# Operadores de maquinaria                      0.500000  0.500000     0.000000
# Pesca y acuicultura                           1.000000  0.000000     0.000000
# Creatividad y diseño                          1.000000  0.000000     0.000000
# Agronomía                                     1.000000  0.000000     0.000000
# Viñedos                                       1.000000  0.000000     0.000000
# Medicina del deporte                          1.000000  0.000000     0.000000
# Derecho ambiental                             1.000000  0.000000     0.000000
# Recursos naturales                            1.000000  0.000000     0.000000
# Desarrollo sustentable                        1.000000  0.000000     0.000000
# Mensajero                                     1.000000  0.000000     0.000000
# Chofer ejecutivo                              0.965517  0.034483     0.000000
# Decoración                                    1.000000  0.000000     0.000000
# Otros                                         1.000000  0.000000     0.000000
# Laboratorista automotriz                      1.000000  0.000000     0.000000
# Radiología                                    1.000000  0.000000     0.000000
# Diseño editorial                              1.000000  0.000000     0.000000
# Química                                       1.000000  0.000000     0.000000
# Hostess                                       1.000000  0.000000     0.000000
# Petroquímica                                  1.000000  0.000000     0.000000
# Intérprete                                    1.000000  0.000000     0.000000
# Makeup artist                                 1.000000  0.000000     0.000000
# Humanidades                                   1.000000  0.000000     0.000000
# Sociología                                    1.000000  0.000000     0.000000
# Montacargas                                   0.959184  0.040816     0.000000
# Educación especial                            1.000000  0.000000     0.000000
# Cocina, bar y cafetería                       0.933333  0.066667     0.000000
# Ecología                                      1.000000  0.000000     0.000000
# Derecho minero y energético                   1.000000  0.000000     0.000000
# Medicina alternativa                          1.000000  0.000000     0.000000
# Cinematografía                                1.000000  0.000000     0.000000

# %%
df.groupby("googleForJobs").count().sort(F.col("count").desc()).show(truncate=False)
# Out:
# +-----------------------------+------+
# |googleForJobs                |count |
# +-----------------------------+------+
# |{GoogleForJobs, true, true}  |139560|
# |{GoogleForJobs, false, false}|2424  |
# |{GoogleForJobs, false, true} |31    |
# +-----------------------------+------+

# %%
subcategories.where("description = 'Flebotomía'").show(truncate=False)
# Out:
# +--------------+-----------+---+-------------------------------------------+
# |__typename    |description|id |url                                        |
# +--------------+-----------+---+-------------------------------------------+
# |JobSubcategory|Flebotomía |401|empleos/trabajo-en-sector-salud-flebotomia/|
# +--------------+-----------+---+-------------------------------------------+

# %%
company_count = df.groupby("company.url").count().sort(F.col("count").desc())
print(company_count.count())
company_count.show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 company_count = df.groupby("company.url").count().sort(F.col("count").desc())
#       2 print(company_count.count())
#       3 company_count.show(truncate=False)
#
# NameError: name 'df' is not defined

# %%
sum = company_count.select(F.sum(F.col("count"))).collect()[0][0]
sum
# Out:
# 142015

# %%
from pyspark.sql.window import Window
ccp = company_count.withColumn("perc", F.col("count") / sum).orderBy(F.col("perc").desc())
window = Window.orderBy(F.col("perc").desc()).rowsBetween(Window.unboundedPreceding, Window.currentRow)
ccp.withColumn("cumsum", F.sum(F.col("perc")).over(window)).show(50, truncate=False)
# Out:
# +------------------------------------------------------------------------+-----+---------------------+-------------------+
# |url                                                                     |count|perc                 |cumsum             |
# +------------------------------------------------------------------------+-----+---------------------+-------------------+
# |null                                                                    |17819|0.125472661338591    |0.125472661338591  |
# |empleos/bolsa-de-trabajo-Test-and-QA-Corporation/                       |9886 |0.06961236489103263  |0.19508502622962365|
# |empleos/bolsa-de-trabajo-grupo-salinas/                                 |6331 |0.04457979790867162  |0.23966482413829526|
# |empleos/bolsa-de-trabajo-Trabajos-Diarios-MX/                           |3222 |0.02268774425236771  |0.26235256839066295|
# |empleos/bolsa-de-trabajo-Un-Mejor-Empleo/                               |3174 |0.022349751786783088 |0.28470232017744607|
# |empleos/bolsa-de-trabajo-Grupo-Salinas/                                 |2236 |0.01574481568848361  |0.3004471358659297 |
# |empleos/bolsa-de-trabajo-gepp/                                          |1604 |0.011294581558286096 |0.3117417174242158 |
# |empleos/bolsa-de-trabajo-truper/                                        |1412 |0.00994261169594761  |0.3216843291201634 |
# |empleos/bolsa-de-trabajo-Adecco/                                        |958  |0.006745766292293068 |0.3284300954124565 |
# |empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/                        |934  |0.006576770059500757 |0.33500686547195724|
# |empleos/bolsa-de-trabajo-Banamex/                                       |912  |0.0064218568461078054|0.34142872231806504|
# |empleos/bolsa-de-trabajo-Santander/                                     |795  |0.005598000211245291 |0.3470267225293103 |
# |empleos/bolsa-de-trabajo-Autofinauto/                                   |744  |0.005238883216561631 |0.35226560574587196|
# |empleos/bolsa-de-trabajo-CitiGroup/                                     |720  |0.00506988698376932  |0.35733549272964127|
# |empleos/bolsa-de-trabajo-bairesdev/                                     |613  |0.004316445445903602 |0.36165193817554486|
# |empleos/bolsa-de-trabajo-Workable-ATS/                                  |503  |0.0035418793789388447|0.3651938175544837 |
# |empleos/bolsa-de-trabajo-Banorte/                                       |469  |0.003302468049149738 |0.36849628560363346|
# |empleos/bolsa-de-trabajo-Atento-Servicios--S--A--de-C-V-/               |427  |0.003006724641763194 |0.37150301024539667|
# |empleos/bolsa-de-trabajo-Tecnologico-de-Monterrey/                      |412  |0.002901101996268    |0.37440411224166464|
# |empleos/bolsa-de-trabajo-BBVA-Bancomer/                                 |373  |0.002626483117980495 |0.3770305953596451 |
# |empleos/bolsa-de-trabajo-EnsenadaHoy-com/                               |364  |0.0025631095306833784|0.3795937048903285 |
# |empleos/bolsa-de-trabajo-Jabil/                                         |362  |0.0025490265112840193|0.38214273140161253|
# |empleos/bolsa-de-trabajo-Seguros-Inbursa--S-A-Grupo-Financiero-Inbursa/ |353  |0.0024856529239869027|0.3846283843255994 |
# |empleos/bolsa-de-trabajo-Michael-Page/                                  |340  |0.002394113297891068 |0.3870224976234905 |
# |empleos/bolsa-de-trabajo-Femsa/                                         |334  |0.0023518642396929902|0.38937436186318347|
# |empleos/bolsa-de-trabajo-marriott-international/                        |330  |0.0023236982008942716|0.39169806006407776|
# |empleos/bolsa-de-trabajo-Teleperformance/                               |326  |0.0022955321620955534|0.3939935922261733 |
# |empleos/bolsa-de-trabajo-Liverpool/                                     |323  |0.0022744076329965146|0.39626799985916983|
# |empleos/bolsa-de-trabajo-Michael-Page-Mexico/                           |311  |0.002189909516600359 |0.3984579093757702 |
# |empleos/bolsa-de-trabajo-Grupo-Santander-Mexico/                        |309  |0.002175826497201    |0.4006337358729712 |
# |empleos/bolsa-de-trabajo-banco-bilbao-vizcaya-argentaria/               |304  |0.0021406189487026017|0.4027743548216738 |
# |empleos/bolsa-de-trabajo-Profuturo/                                     |302  |0.0021265359293032426|0.404900890750977  |
# |empleos/bolsa-de-trabajo-Continental-AG/                                |287  |0.0020209132838080483|0.40692180403478506|
# |empleos/bolsa-de-trabajo-VincuVentas-MX/                                |281  |0.0019786642256099706|0.40890046826039506|
# |empleos/bolsa-de-trabajo-Qualitas-Compania-de-Seguros/                  |275  |0.001936415167411893 |0.41083688342780694|
# |empleos/bolsa-de-trabajo-Grupo-Nacional-Provincial/                     |273  |0.001922332148012534 |0.41275921557581946|
# |empleos/bolsa-de-trabajo-Probecarios-com/                               |269  |0.0018941661092138154|0.4146533816850333 |
# |empleos/bolsa-de-trabajo-American-Eagle-Outfitters/                     |264  |0.0018589585607154174|0.41651234024574874|
# |empleos/bolsa-de-trabajo-Cemex-Holdings/                                |259  |0.0018237510122170193|0.4183360912579658 |
# |empleos/bolsa-de-trabajo-Softtek/                                       |259  |0.0018237510122170193|0.4201598422701828 |
# |empleos/bolsa-de-trabajo-Universidad-Autonoma-del-Estado-de-Mexico/     |258  |0.0018167095025173397|0.42197655177270016|
# |empleos/bolsa-de-trabajo-Worken/                                        |258  |0.0018167095025173397|0.4237932612752175 |
# |empleos/bolsa-de-trabajo-Sociedad-Nacional-Promotora-de-Becarios-S-C-/  |257  |0.0018096679928176602|0.42560292926803517|
# |empleos/bolsa-de-trabajo-flex-ltd-/                                     |251  |0.0017674189346195824|0.42737034820265474|
# |empleos/bolsa-de-trabajo-Bosch-Group/                                   |247  |0.001739252895820864 |0.4291096010984756 |
# |empleos/bolsa-de-trabajo-CREDICLUB-SA-DE-CV-SOCIEDAD-FINANCIERA-POPULAR/|246  |0.0017322113861211843|0.4308418124845968 |
# |empleos/bolsa-de-trabajo-LosEconomicos-com/                             |237  |0.001668837798824068 |0.43251065028342084|
# |empleos/bolsa-de-trabajo-Gentera/                                       |236  |0.0016617962891243882|0.4341724465725452 |
# |empleos/bolsa-de-trabajo-PepsiCo/                                       |235  |0.0016547547794247086|0.43582720135196995|
# |empleos/bolsa-de-trabajo-pepsico/                                       |233  |0.0016406717600253495|0.4374678731119953 |
# +------------------------------------------------------------------------+-----+---------------------+-------------------+
# only showing top 50 rows

# %%
df.where("company.url='empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/'").count()
# Out:
# 934

# %%
df.select("company.name").where("company.confidential=TRUE").count()
# Out:
# 17813

# %%
company_count = df.where("redirect.type != 2").groupby("company.url").count().sort(F.col("count").desc())
company_count.show(truncate=False)
# Out:
# +-----------------------------------------------------------------------+-----+
# |url                                                                    |count|
# +-----------------------------------------------------------------------+-----+
# |null                                                                   |17261|
# |empleos/bolsa-de-trabajo-Grupo-Salinas/                                |1919 |
# |empleos/bolsa-de-trabajo-Adecco/                                       |958  |
# |empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/                       |934  |
# |empleos/bolsa-de-trabajo-Banamex/                                      |912  |
# |empleos/bolsa-de-trabajo-Autofinauto/                                  |744  |
# |empleos/bolsa-de-trabajo-Santander/                                    |544  |
# |empleos/bolsa-de-trabajo-Banorte/                                      |469  |
# |empleos/bolsa-de-trabajo-Atento-Servicios--S--A--de-C-V-/              |427  |
# |empleos/bolsa-de-trabajo-BBVA-Bancomer/                                |373  |
# |empleos/bolsa-de-trabajo-Seguros-Inbursa--S-A-Grupo-Financiero-Inbursa/|353  |
# |empleos/bolsa-de-trabajo-Michael-Page/                                 |340  |
# |empleos/bolsa-de-trabajo-Femsa/                                        |334  |
# |empleos/bolsa-de-trabajo-Teleperformance/                              |326  |
# |empleos/bolsa-de-trabajo-Liverpool/                                    |323  |
# |empleos/bolsa-de-trabajo-Profuturo/                                    |302  |
# |empleos/bolsa-de-trabajo-Qualitas-Compania-de-Seguros/                 |275  |
# |empleos/bolsa-de-trabajo-Grupo-Nacional-Provincial/                    |273  |
# |empleos/bolsa-de-trabajo-Universidad-Autonoma-del-Estado-de-Mexico/    |258  |
# |empleos/bolsa-de-trabajo-Softtek/                                      |257  |
# +-----------------------------------------------------------------------+-----+
# only showing top 20 rows

# %%
company_count = df.where("redirect.type == 2").groupby("company.url").count().sort(F.col("count").desc())
company_count.show(truncate=False)
# Out:
# +---------------------------------------------------------+-----+
# |url                                                      |count|
# +---------------------------------------------------------+-----+
# |empleos/bolsa-de-trabajo-Test-and-QA-Corporation/        |9886 |
# |empleos/bolsa-de-trabajo-grupo-salinas/                  |6331 |
# |empleos/bolsa-de-trabajo-Trabajos-Diarios-MX/            |3222 |
# |empleos/bolsa-de-trabajo-Un-Mejor-Empleo/                |3174 |
# |empleos/bolsa-de-trabajo-gepp/                           |1604 |
# |empleos/bolsa-de-trabajo-truper/                         |1412 |
# |empleos/bolsa-de-trabajo-CitiGroup/                      |720  |
# |empleos/bolsa-de-trabajo-bairesdev/                      |613  |
# |null                                                     |558  |
# |empleos/bolsa-de-trabajo-Workable-ATS/                   |503  |
# |empleos/bolsa-de-trabajo-EnsenadaHoy-com/                |364  |
# |empleos/bolsa-de-trabajo-Jabil/                          |362  |
# |empleos/bolsa-de-trabajo-marriott-international/         |330  |
# |empleos/bolsa-de-trabajo-Grupo-Salinas/                  |317  |
# |empleos/bolsa-de-trabajo-Michael-Page-Mexico/            |311  |
# |empleos/bolsa-de-trabajo-Grupo-Santander-Mexico/         |309  |
# |empleos/bolsa-de-trabajo-banco-bilbao-vizcaya-argentaria/|304  |
# |empleos/bolsa-de-trabajo-Tecnologico-de-Monterrey/       |298  |
# |empleos/bolsa-de-trabajo-Continental-AG/                 |287  |
# |empleos/bolsa-de-trabajo-VincuVentas-MX/                 |281  |
# +---------------------------------------------------------+-----+
# only showing top 20 rows

# %%
df.where("company.url == 'empleos/bolsa-de-trabajo-bairesdev/'").first()
# Out:
# Row(Job:value='Job:17037115', __typename='Job', applied=False, autoinclusion=Row(__typename='JobAutoinclusion', autoinclusion=True, source='asp'), bullets=[], category=Row(__ref='JobCategory:17'), company=Row(__typename='JobCompany', confidential=False, logoUrl='https://cdn-h4.occ.com.mx/images/logos/300x300/01/01RfAPA_ZZ_STrdMpwQ-DQ2.jpg', name='bairesdev', namePretty='bairesdev', profile=None, rel=None, url='empleos/bolsa-de-trabajo-bairesdev/'), contact=Row(__typename='JobContact', emailAddress='', name='', phoneNumber='', showContactInfo=False), dates=Row(__typename='JobDates', active='2023-07-13 20:49:58', expires='2023-07-15 00:00:00', publish='2023-07-12 00:00:00'), description='Who We are   BairesDev is proud to be the fastest-growing company in America. With people in five continents and world-class clients, we are only as strong as the multicultural teams at the heart of o ...', education=Row(__typename='JobEducation', level='NOT_SPECIFIED', url='empleos/nivel-posgrado/'), friendlyId='17037115-react-engineer-remote-work', googleForJobs=Row(__typename='GoogleForJobs', isGoogleForJobs=True, isGoogleIndexed=True), hiring=Row(__typename='JobHiring', contract=False, fullTime=False, partTime=False, permanent=True, temporary=False, url='empleos/permanente/'), id='17037115', jobBody='Who We are<br> <br>BairesDev is proud to be the fastest-growing company in America. With people in five continents and world-class clients, we are only as strong as the multicultural teams at the heart of our business. To consistently deliver the highest quality solutions to our clients, we only hire the Top 1% of the best talents and nurture their professional growth on exciting projects. <br><br>React Engineer at BairesDev <br> <br>Being a React Engineer in our Development Team is just like being a full-time problem solver. We expect your abilities to be a combination of experience, knowledge, and independence. Innovation is also at the heart of the BairesDev strategy. So, if you were willing to take on the most complex tasks and be a master of your tech stack, React, then you are probably one of those unique we&#39;re looking for. <BR>You will face numerous technical challenges, so you must use current technologies, and get involved in the mobile world, web applications, devices, etc.<br><br>What You Will Do:<br> <br>- Design practical solutions to solve problems. <BR>- Participate in code reviews and testing. <BR>- Provide the technology for a platform that facilitates monthly requests. <BR>- Work with big data and predictive analytics on a distributed system. <BR>- Collaborate with the developing team, product owners, and client services, to innovate and get the tasks done.<br><br>Here is what we are looking for:<br> <br>- 5+ years of experience in Front End development with strong skills in Javascript, CSS3, and HTML5.<BR>- 1+ of experience developing Web applications using ReactJS, Flux, Redux, Relay, etc.<BR>- Experience with other Javascript Frameworks such as Angular, Backbone, and Marionette.<BR>- Experience using ES2015 (ES6 / ES7).<BR>- Experience with command lines, APIs, and client-side performance.<BR>- Familiar with the concepts of basic programming, data structures, types of variables, and idiosyncrasies.<BR>- Advanced English level.<br><br>How we do make your work (and your life) easier:<br> <br>- 100% remote work.<BR>- Hardware setup for you to work from home.<BR>- Flexible hours - make your schedule.<BR>- Paid parental leave, vacation & holidays.<BR>- Diverse and multicultural work environment.<BR>- An innovative environment with the structure and resources of a leading multinational.<BR>- Excellent compensation - well above the market average.<BR>- Here you can grow at the speed of your learning curve.<br><br>Our people work remotely but with a consistent and robust culture that promotes diversity and teamwork. To continue being the leading software development company in Latin America, we want to ensure that every BairesDe ...

# %%
df.where("redirect.isRedirected == TRUE").where("autoinclusion.autoinclusion == TRUE").count()
# Out:
# 56154

# %%
df.where("redirect.isRedirected == TRUE").where("autoinclusion.autoinclusion == FALSE").count()
# Out:
# 2326

# %%
df.where("redirect.isRedirected == FALSE").where("autoinclusion.autoinclusion == TRUE").count()
# Out:
# 0

# %%
df.where("redirect.isRedirected == FALSE").where("autoinclusion.autoinclusion == FALSE").count()
# Out:
# 83535

# %%
df.where("redirect.isRedirected == TRUE")\
    .where("autoinclusion.autoinclusion == TRUE")\
    .select(["scraped_url", "redirect.externalUrl"])\
    .show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+
# |scraped_url                                                                                        |externalUrl                                                                                                                                              |
# +---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+
# |https://www.occ.com.mx/empleo/oferta/17025688-full-stack-engineer/                                 |https://paypal.eightfold.ai/careers/job?pid=274893560254                                                                                                 |
# |https://www.occ.com.mx/empleo/oferta/16905959-producer-cnn-espanol/                                |https://warnerbros.wd5.myworkdayjobs.com/en-US/global/job/Mexico-City-Paseo-dl-Reforma/Producer--CNN-Espaol_R000069816                                   |
# |https://www.occ.com.mx/empleo/oferta/16906299-sr-producer-cnn-espanol/                             |https://warnerbros.wd5.myworkdayjobs.com/en-US/global/job/Mexico-City-Paseo-dl-Reforma/Sr-Producer_R000069688                                            |
# |https://www.occ.com.mx/empleo/oferta/16971648-web-editor/                                          |https://careers.wbd.com/global/en/job/R000070289                                                                                                         |
# |https://www.occ.com.mx/empleo/oferta/17008790-data-scientist-1/                                    |https://paypal.eightfold.ai/careers/job?pid=274894798100                                                                                                 |
# |https://www.occ.com.mx/empleo/oferta/16861928-software-developer/                                  |https://paypal.eightfold.ai/careers/job?pid=274894512856                                                                                                 |
# |https://www.occ.com.mx/empleo/oferta/16884097-news-desk-journalist/                                |https://careers.wbd.com/global/en/job/R000069686                                                                                                         |
# |https://www.occ.com.mx/empleo/oferta/16971827-senior-sourcing-manager/                             |https://jobs.smartrecruiters.com/Visa/743999915627893-senior-sourcing-manager                                                                            |
# |https://www.occ.com.mx/empleo/oferta/17008842-manager-decision-science-2/                          |https://paypal.eightfold.ai/careers/job?pid=274894798098                                                                                                 |
# |https://www.occ.com.mx/empleo/oferta/16884239-software-developer-full-stack/                       |https://paypal.eightfold.ai/careers/job?pid=274894484905                                                                                                 |
# |https://www.occ.com.mx/empleo/oferta/16971806-manager-product-experience-design/                   |https://mastercard.wd1.myworkdayjobs.com/en-US/CorporateCareers/job/Mexico-City-Mexico/Manager--Product-Experience-Design_R-197468                       |
# |https://www.occ.com.mx/empleo/oferta/16971633-manager-controllership-tv-production-/               |https://careers.wbd.com/global/en/job/R000070125                                                                                                         |
# |https://www.occ.com.mx/empleo/oferta/16754221-finance-controllership-analyst-level-6-/             |https://generalmotors.wd5.myworkdayjobs.com/Careers_GM/job/Ramos-Arizpe-Coahuila-Mexico/Finance-Controllership-Analyst----Level-6-_JR-202309588          |
# |https://www.occ.com.mx/empleo/oferta/16753832-senior-analyst-information-security-risk/            |https://careers.wbd.com/global/en/job/R000069085                                                                                                         |
# |https://www.occ.com.mx/empleo/oferta/16971722-business-intelligence-b-i-senior-analyst/            |https://careers.wtwco.com/job/18663671/business-intelligence-b-i-senior-analyst-miguel-hidalgo-mx/                                                       |
# |https://www.occ.com.mx/empleo/oferta/16827873-lider-de-grupo-de-mantenimiento-carrocerias-nivel-6-/|https://generalmotors.wd5.myworkdayjobs.com/Careers_GM/job/Ramos-Arizpe-Coahuila-Mexico/Lder-de-Grupo-de--Mantenimiento-Carroceras--Nivel-6-_JR-202308775|
# |https://www.occ.com.mx/empleo/oferta/17043966-almacenista/                                         |https://empleo.gob.mx/resultados-ss-detalle/empleo/20362317                                                                                              |
# |https://www.occ.com.mx/empleo/oferta/17043968-comprador/                                           |https://empleo.gob.mx/resultados-ss-detalle/empleo/20362323                                                                                              |
# |https://www.occ.com.mx/empleo/oferta/17043963-jefe-de-piso-/                                       |https://empleo.gob.mx/resultados-ss-detalle/empleo/20362310                                                                                              |
# |https://www.occ.com.mx/empleo/oferta/17043959-promo-vendedor/                                      |https://empleo.gob.mx/resultados-ss-detalle/empleo/20362302                                                                                              |
# +---------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
