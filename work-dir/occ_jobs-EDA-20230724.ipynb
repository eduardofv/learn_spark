# %% [markdown]
# # Structure Check
#
# Cómo tener acceso a los JSON internos de los registros.
#
# Es necesario definir un schema. Abajo se ve cómo inferir schema a partir de un ejemplo

# %%
import pandas as pd
import matplotlib.pyplot as plt

import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F


spark = SparkSession \
    .builder \
    .appName("Learning Spark") \
    .getOrCreate()

date_str = "20230724"

#df = spark.read.json("harvester/occ/tests/test-gdl.jsonl")
#df = spark.read.json("harvester/occ/tests/test-cdmx/sneaky*.jsonl.gz")
#df = spark.read.json("test-cdmx.jsonl") #from ETL
#df = spark.read.json("test-full-occ.jsonl") #from ETL
df = spark.read.json(f"occ-{date_str}.jsonl")
categories = spark.read.json(f"occ-{date_str}-categories.json")
subcategories = spark.read.json(f"occ-{date_str}-subcategories.json")

# %%
#categories.count(), categories.printSchema()
#subcategories.show()

# %%
df.count(), df.printSchema()
# Out:
# root
#  |-- Job:value: string (nullable = true)
#  |-- __typename: string (nullable = true)
#  |-- applied: boolean (nullable = true)
#  |-- autoinclusion: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- autoinclusion: boolean (nullable = true)
#  |    |-- source: string (nullable = true)
#  |-- bullets: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- __ref: string (nullable = true)
#  |-- category: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- company: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- confidential: boolean (nullable = true)
#  |    |-- logoUrl: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- namePretty: string (nullable = true)
#  |    |-- profile: struct (nullable = true)
#  |    |    |-- __ref: string (nullable = true)
#  |    |-- rel: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- contact: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- emailAddress: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- phoneNumber: string (nullable = true)
#  |    |-- showContactInfo: boolean (nullable = true)
#  |-- dates: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- active: string (nullable = true)
#  |    |-- expires: string (nullable = true)
#  |    |-- publish: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- education: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- level: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- friendlyId: string (nullable = true)
#  |-- googleForJobs: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- isGoogleForJobs: boolean (nullable = true)
#  |    |-- isGoogleIndexed: boolean (nullable = true)
#  |-- hiring: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- contract: boolean (nullable = true)
#  |    |-- fullTime: boolean (nullable = true)
#  |    |-- partTime: boolean (nullable = true)
#  |    |-- permanent: boolean (nullable = true)
#  |    |-- temporary: boolean (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- jobBody: string (nullable = true)
#  |-- jobType: string (nullable = true)
#  |-- level: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- location: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- locations: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |-- city: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- jobCity: string (nullable = true)
#  |    |    |    |    |-- rel: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- country: struct (nullable = true)
#  |    |    |    |    |-- __ref: string (nullable = true)
#  |    |    |    |-- locationId: string (nullable = true)
#  |    |    |    |-- placeId: string (nullable = true)
#  |    |    |    |-- state: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- abbreviation: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- rel: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- zone: struct (nullable = true)
#  |    |    |    |    |-- __typename: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- profileId: string (nullable = true)
#  |-- redirect: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- externalUrl: string (nullable = true)
#  |    |-- isRedirected: boolean (nullable = true)
#  |    |-- redirected: boolean (nullable = true)
#  |    |-- type: long (nullable = true)
#  |-- requisition: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- salary: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- from: long (nullable = true)
#  |    |-- performanceCompensation: long (nullable = true)
#  |    |-- show: boolean (nullable = true)
#  |    |-- time: long (nullable = true)
#  |    |-- to: long (nullable = true)
#  |    |-- variableCompensation: long (nullable = true)
#  |-- scraped_at: string (nullable = true)
#  |-- scraped_by_uuid: string (nullable = true)
#  |-- scraped_crawler: string (nullable = true)
#  |-- scraped_identifier: string (nullable = true)
#  |-- scraped_record_version: string (nullable = true)
#  |-- scraped_url: string (nullable = true)
#  |-- scraped_uuid: string (nullable = true)
#  |-- simVal: string (nullable = true)
#  |-- skill: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- hasSkills: boolean (nullable = true)
#  |    |-- skills: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- __ref: string (nullable = true)
#  |-- subcategory: struct (nullable = true)
#  |    |-- __ref: string (nullable = true)
#  |-- tags: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- lessThan20: boolean (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- workMode: struct (nullable = true)
#  |    |-- __typename: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- url: string (nullable = true)
# (137284, None)

# %%
#df.toPandas()
df.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Job:value              | Job:17058478
#  __typename             | Job
#  applied                | false
#  autoinclusion          | {JobAutoinclusion, false, }
#  bullets                | [{JobBullet:1833246}, {JobBullet:1833247}]
#  category               | {JobCategory:5}
#  company                | {JobCompany, true, https://cdn-h4.occ.com.mx/images/logos/common/no_logo_confidencial.jpg, Empresa confidencial, , null, null, null}
#  contact                | {JobContact, , , , true}
#  dates                  | {JobDates, 2023-07-18 19:09:08, 2023-09-16 23:59:59, 2023-07-18 00:00:00}
#  description            | Seguimiento y Coordinación de los Proyectos, a través de procesos de control, revisión y supervisión que permita un eficiente flujo de información a Obra  Revisión constante del presupuesto.  Correcta ...
#  education              | {JobEducation, ACADEMIC_WITH_DEGREE, empleos/}
#  friendlyId             | 17058478-gerente-de-proyectos-y-construccion
#  googleForJobs          | {GoogleForJobs, true, true}
#  hiring                 | {JobHiring, false, true, false, true, false, empleos/permanente/}
#  id                     | 17058478
#  jobBody                | <p>Seguimiento y Coordinaci&oacute;n de los Proyectos, a trav&eacute;s de procesos de control, revisi&oacute;n y supervisi&oacute;n que permita un eficiente flujo de informaci&oacute;n a Obra</p><p>Revisi&oacute;n constante del presupuesto.</p><p>Correcta aplicaci&oacute;n de la metodolog&iacute;a BIM.</p><p>Coordinar las actividades de equipo de trabajo </p><p>Coordinar proyectistas externos para la elaboraci&oacute;n de proyectos arquitect&oacute;nicos, estructurales y de instalaciones necesarios para la construcci&oacute;n de un proyecto.&nbsp; \t</p><p><br></p><p>Experiencia:</p><p><br></p><p>* Interpretacion de Estudios Preliminares\t\t</p><p>* Conocimiento y manejo de reporte de elaboraci&oacute;n de Proyectos\t\t</p><p>* Conocimiento en supervisi&oacute;n de obra\t\t</p><p>* Liderazgo, negociaci&oacute;n y delegaci&oacute;n de actividades.\t\t</p><p>" *Elaboraci&oacute;n Revisi&oacute;n y coordinaci&oacute;n de proyectos (Arquitect&oacute;nicos, Estructurales y de Instalaciones).</p><p>*Conocimiento el los flujos de trabajo que demanda la metodolog&iacute;a BIM, basada en est&aacute;dares internacionales y locales de la industria."\t\t</p><p><br></p><p>   Navisworks   Revit&nbsp;(tres disciplinas)   Autodesk Design Review </p><p><br></p><p><br></p><p>Revisar y validar los proyectos antes de entregar a Obra\t\t</p><p>Integrar y coordinar los proyectos con las &aacute;reas de ingenier&iacute;as y analistas de proyectos.\t\t</p><p>Revisar y validar el&nbsp;proceso constructivo en presupuestos y Construcci&oacute;n - en sitio\t\t</p><p>Gestionar la aprobacion de proyectos con cliente externo en coordinacion Gerente de Proyectos - en sitio\t\t</p><p>Validar el proyecto ejecutivo contra presupuesto, en coordinacion con Gerente de Proyectos y GIV o GBIM\t\t</p><p>Participar en Comites de Seguimiento y Control de Proyectos y Obras\t\t</p><p><br></p>
#  jobType                | STANDOUT
#  level                  | {JobLevel:}
#  location               | {JobLocation, Zapopan, Jalisco, [{JobLocationData, {CityLocation, Zapopan, Zapopan, null, empleos/en-jalisco/en-la-ciudad-de-zapopan/}, {CountryLocation:MX}, 275, 60115, {StateLocation, Jal., Jalisco, null, empleos/en-jalisco/}, {ZoneLocation, }}], empleos-en-jalisco}
#  profileId              | 165151265883347
#  redirect               | {JobRedirect, , false, false, 0}
#  requisition            | {JobRequisition:}
#  salary                 | {JobSalary, 26000, 0, true, 0, 28000, 0}
#  scraped_at             | 2023-07-24 13:01:47.934818
# ...
#  scraped_uuid           | 66874472-c2a8-4644-bec6-b64810836314
#  simVal                 | null
#  skill                  | {JobSkills, false, []}
#  subcategory            | {JobSubcategory:136}
#  tags                   | {JobTags, false}
#  title                  | Gerente de proyectos y construcción
#  url                    | /empleo/oferta/17058478-gerente-de-proyectos-y-construccion?rank=1&page=1&sessionid=&userid=&uuid=7afe881f-8a25-4db3-8912-0842b58516d4&origin=unknown&type=1&ai=false&ais=&showseo=true&returnURL=%2Fempleos-en-mexico-y-el-mundo%3Fsessionid%3D%26userid%3D%231
#  workMode               | {JobWorkMode, IN_PERSON, empleos/tipo-en-oficina/}
# only showing top 1 row

# %%
df.count(), df.select('id').distinct().count()
# Out:
# (137284, 133901)

# %%
df.groupby("redirect.type").count().show()
# Out:
# +----+-----+
# |type|count|
# +----+-----+
# |   0|77150|
# |   1| 3840|
# |   2|56294|
# +----+-----+

# %%
df.groupby("jobType").count().show()
# Out:
# +--------+------+
# | jobType| count|
# +--------+------+
# | PREMIUM|  3170|
# |STANDOUT| 28321|
# | CLASSIC|105793|
# +--------+------+

# %%
df.groupby("jobType").pivot("redirect.type").count().show()
# Out:
# +--------+-----+----+-----+
# | jobType|    0|   1|    2|
# +--------+-----+----+-----+
# | PREMIUM| 3145|  25| null|
# |STANDOUT|27851| 312|  158|
# | CLASSIC|46154|3503|56136|
# +--------+-----+----+-----+

# %%
pdf = df.groupby("jobType").pivot("redirect.type").count().toPandas().fillna(0).set_index('jobType')
pdf.columns = ['NoRedir', 'Redir1', 'Redir2']
pdf.div(pdf.sum(axis=1), axis=0)
# Out:
#            NoRedir    Redir1    Redir2
# jobType
# PREMIUM   0.992114  0.007886  0.000000
# STANDOUT  0.983405  0.011017  0.005579
# CLASSIC   0.436267  0.033112  0.530621

# %%
pdf.div(pdf.sum(axis=0), axis=1)
# Out:
#            NoRedir   Redir1    Redir2
# jobType
# PREMIUM   0.040765  0.00651  0.000000
# STANDOUT  0.360998  0.08125  0.002807
# CLASSIC   0.598237  0.91224  0.997193

# %%
pdf.div(pdf.sum(axis=None))
# Out:
#            NoRedir   Redir1    Redir2
# jobType
# PREMIUM   0.040765  0.00651  0.000000
# STANDOUT  0.360998  0.08125  0.002807
# CLASSIC   0.598237  0.91224  0.997193

# %%
cat_count = df.groupby("category").count().orderBy(F.col("count").desc())
split_col = F.split(cat_count["category.__ref"].cast("String"), ":")
cat_count = cat_count.withColumn("category_id", split_col.getItem(1).cast("INT"))
cat_count = cat_count.join(categories.select("id", "description"), cat_count.category_id == categories.id, how="inner")
cat_count = cat_count.select(["category_id", "description", "count"]).orderBy(F.col("count").desc())

# %%
sum = cat_count.select(F.sum("count")).collect()[0][0]
cat_count = cat_count.withColumn("percentage", F.col("count") / sum)
cat_count.show(cat_count.count(), truncate=False)
# Out:
# +-----------+------------------------------------------------+-----+---------------------+
# |category_id|description                                     |count|percentage           |
# +-----------+------------------------------------------------+-----+---------------------+
# |19         |Ventas                                          |29980|0.21837941784913026  |
# |1          |Administrativo                                  |16111|0.11735526354127211  |
# |17         |Tecnologías de la Información - Sistemas        |15055|0.10966317997727339  |
# |4          |Contabilidad - Finanzas                         |13767|0.10028116896360828  |
# |10         |Logística - Transporte - Distribución - Almacén |11300|0.08231112147081962  |
# |11         |Manufactura - Producción - Operación            |10276|0.07485213134815419  |
# |9          |Ingeniería                                      |7938 |0.057821741790740365 |
# |21         |Atención a clientes - Call Center               |6989 |0.05090906442119985  |
# |13         |Recursos humanos                                |5440 |0.03962588502666006  |
# |23         |Servicios generales - Oficios - Seguridad       |4018 |0.02926779522741179  |
# |5          |Construcción - Inmobiliaria - Arquitectura      |2798 |0.020381107776579935 |
# |15         |Sector salud                                    |2798 |0.020381107776579935 |
# |12         |Mercadotecnia - Publicidad - Relaciones Públicas|2749 |0.02002418344453833  |
# |18         |Turismo - Hospitalidad - Gastronomía            |2298 |0.01673902275574721  |
# |16         |Seguros y reaseguros                            |1377 |0.010030302147373328 |
# |8          |Educación                                       |1376 |0.010023017977331662 |
# |7          |Derecho y leyes                                 |1006 |0.007327875061915445 |
# |6          |Arte y diseño                                   |789  |0.005747210162874042 |
# |3          |Comunicación y creatividad                      |497  |0.00362023251070773  |
# |2          |Minería - Energía - Recursos Naturales          |228  |0.0016607907694997232|
# |20         |Veterinaria - Agricultura                       |196  |0.0014276973281664286|
# |14         |Deportes - Salud - Belleza                      |174  |0.0012674455872497888|
# |22         |Ciencias sociales - Humanidades                 |86   |6.264386235832289E-4 |
# |0          |                                                |38   |2.767984615832872E-4 |
# +-----------+------------------------------------------------+-----+---------------------+

# %%
split_col = F.split(df["category.__ref"].cast("String"), ":")
cat_count_redir = df.withColumn("category_id", split_col.getItem(1).cast("INT"))
cat_count_redir = cat_count_redir.groupby("category_id").pivot("redirect.type").count()
cat_count_redir = cat_count_redir.join(categories.select("id", "description"), cat_count_redir.category_id == categories.id, how="inner")
cat_count_redir = cat_count_redir.select(["description", "0", "1", "2"]).sort(F.col("0").desc()).toPandas().fillna(0)
cat_count_redir.columns = ["Category", "NoRedir", "Redir1", "Redir2(AGG)"]
cat_count_redir = cat_count_redir.set_index("Category")
cat_count_redir = cat_count_redir.div(cat_count_redir.sum(axis=1), axis=0)
cat_count_redir
# Out:
#                                                    NoRedir    Redir1  \
# Category
# Ventas                                            0.546898  0.037525
# Contabilidad - Finanzas                           0.650033  0.029128
# Tecnologías de la Información - Sistemas          0.534773  0.039987
# Logística - Transporte - Distribución - Almacén   0.576637  0.011062
# Administrativo                                    0.403637  0.016883
# Manufactura - Producción - Operación              0.536687  0.016933
# Ingeniería                                        0.628874  0.025699
# Recursos humanos                                  0.738235  0.031801
# Atención a clientes - Call Center                 0.432823  0.023036
# Construcción - Inmobiliaria - Arquitectura        0.830593  0.018585
# Sector salud                                      0.774839  0.016798
# Mercadotecnia - Publicidad - Relaciones Públicas  0.683885  0.017097
# Servicios generales - Oficios - Seguridad         0.349676  0.034843
# Turismo - Hospitalidad - Gastronomía              0.477372  0.009138
# Seguros y reaseguros                              0.748729  0.167756
# Educación                                         0.726744  0.003634
# Derecho y leyes                                   0.815109  0.031809
# Arte y diseño                                     0.737643  0.011407
# Comunicación y creatividad                        0.716298  0.014085
# Minería - Energía - Recursos Naturales            0.824561  0.017544
# Veterinaria - Agricultura                         0.770408  0.020408
# Deportes - Salud - Belleza                        0.655172  0.011494
# Ciencias sociales - Humanidades                   0.825581  0.023256
#                                                   0.000000  0.000000
#
#                                                   Redir2(AGG)
# Category
# Ventas                                               0.415577
# Contabilidad - Finanzas                              0.320840
# Tecnologías de la Información - Sistemas             0.425241
# Logística - Transporte - Distribución - Almacén      0.412301
# Administrativo                                       0.579480
# Manufactura - Producción - Operación                 0.446380
# Ingeniería                                           0.345427
# Recursos humanos                                     0.229963
# Atención a clientes - Call Center                    0.544141
# Construcción - Inmobiliaria - Arquitectura           0.150822
# Sector salud                                         0.208363
# Mercadotecnia - Publicidad - Relaciones Públicas     0.299018
# Servicios generales - Oficios - Seguridad            0.615480
# Turismo - Hospitalidad - Gastronomía                 0.513490
# Seguros y reaseguros                                 0.083515
# Educación                                            0.269622
# Derecho y leyes                                      0.153082
# Arte y diseño                                        0.250951
# Comunicación y creatividad                           0.269618
# Minería - Energía - Recursos Naturales               0.157895
# Veterinaria - Agricultura                            0.209184
# Deportes - Salud - Belleza                           0.333333
# Ciencias sociales - Humanidades                      0.151163
#                                                      1.000000

# %%
cat_count_redir.sort_values("Redir2(AGG)", ascending=False)
# Out:
#                                                    NoRedir    Redir1  \
# Category
#                                                   0.000000  0.000000
# Servicios generales - Oficios - Seguridad         0.349676  0.034843
# Administrativo                                    0.403637  0.016883
# Atención a clientes - Call Center                 0.432823  0.023036
# Turismo - Hospitalidad - Gastronomía              0.477372  0.009138
# Manufactura - Producción - Operación              0.536687  0.016933
# Tecnologías de la Información - Sistemas          0.534773  0.039987
# Ventas                                            0.546898  0.037525
# Logística - Transporte - Distribución - Almacén   0.576637  0.011062
# Ingeniería                                        0.628874  0.025699
# Deportes - Salud - Belleza                        0.655172  0.011494
# Contabilidad - Finanzas                           0.650033  0.029128
# Mercadotecnia - Publicidad - Relaciones Públicas  0.683885  0.017097
# Educación                                         0.726744  0.003634
# Comunicación y creatividad                        0.716298  0.014085
# Arte y diseño                                     0.737643  0.011407
# Recursos humanos                                  0.738235  0.031801
# Veterinaria - Agricultura                         0.770408  0.020408
# Sector salud                                      0.774839  0.016798
# Minería - Energía - Recursos Naturales            0.824561  0.017544
# Derecho y leyes                                   0.815109  0.031809
# Ciencias sociales - Humanidades                   0.825581  0.023256
# Construcción - Inmobiliaria - Arquitectura        0.830593  0.018585
# Seguros y reaseguros                              0.748729  0.167756
#
#                                                   Redir2(AGG)
# Category
#                                                      1.000000
# Servicios generales - Oficios - Seguridad            0.615480
# Administrativo                                       0.579480
# Atención a clientes - Call Center                    0.544141
# Turismo - Hospitalidad - Gastronomía                 0.513490
# Manufactura - Producción - Operación                 0.446380
# Tecnologías de la Información - Sistemas             0.425241
# Ventas                                               0.415577
# Logística - Transporte - Distribución - Almacén      0.412301
# Ingeniería                                           0.345427
# Deportes - Salud - Belleza                           0.333333
# Contabilidad - Finanzas                              0.320840
# Mercadotecnia - Publicidad - Relaciones Públicas     0.299018
# Educación                                            0.269622
# Comunicación y creatividad                           0.269618
# Arte y diseño                                        0.250951
# Recursos humanos                                     0.229963
# Veterinaria - Agricultura                            0.209184
# Sector salud                                         0.208363
# Minería - Energía - Recursos Naturales               0.157895
# Derecho y leyes                                      0.153082
# Ciencias sociales - Humanidades                      0.151163
# Construcción - Inmobiliaria - Arquitectura           0.150822
# Seguros y reaseguros                                 0.083515

# %%
subcat_count = df.groupby("subcategory").count().orderBy(F.col("count").desc())
split_col = F.split(subcat_count["subcategory.__ref"].cast("String"), ":")
subcat_count = subcat_count.withColumn("subcategory_id", split_col.getItem(1).cast("INT"))
subcat_count = subcat_count.join(subcategories.select("id", "description"), subcat_count.subcategory_id == subcategories.id, how="inner")
subcat_count.orderBy(F.col("count").desc()).show(25)
# Out:
# +--------------------+-----+--------------+---+--------------------+
# |         subcategory|count|subcategory_id| id|         description|
# +--------------------+-----+--------------+---+--------------------+
# | {JobSubcategory:29}| 9429|            29| 29|      Administración|
# |{JobSubcategory:319}| 6166|           319|319|   Ventas en general|
# |{JobSubcategory:260}| 5943|           260|260| Atención al cliente|
# |{JobSubcategory:242}| 4001|           242|242|Desarrollo de sof...|
# |{JobSubcategory:149}| 3998|           149|149|Almacén - Inventario|
# |{JobSubcategory:275}| 3470|           275|275|Administración de...|
# | {JobSubcategory:25}| 3268|            25| 25|  Crédito y cobranza|
# |{JobSubcategory:286}| 3191|           286|286|     Ventas de campo|
# | {JobSubcategory:78}| 3059|            78| 78|        Contabilidad|
# |{JobSubcategory:190}| 2107|           190|190|Reclutamiento y s...|
# |{JobSubcategory:424}| 1950|           424|424|              Cajero|
# | {JobSubcategory:30}| 1856|            30| 30|  Control de Calidad|
# |  {JobSubcategory:2}| 1704|             2|  2|Auxiliar administ...|
# |{JobSubcategory:251}| 1658|           251|251|     Soporte técnico|
# |{JobSubcategory:304}| 1640|           304|304|Mantenimiento gen...|
# |{JobSubcategory:237}| 1634|           237|237|Administración de...|
# |{JobSubcategory:285}| 1591|           285|285| Ventas corporativas|
# |{JobSubcategory:192}| 1581|           192|192|           Seguridad|
# |{JobSubcategory:289}| 1561|           289|289|Promotor - Demost...|
# |{JobSubcategory:287}| 1546|           287|287|Venta al detalle ...|
# |{JobSubcategory:150}| 1475|           150|150|              Chofer|
# | {JobSubcategory:18}| 1442|            18| 18|Ingeniería indust...|
# | {JobSubcategory:15}| 1440|            15| 15|             Compras|
# |{JobSubcategory:307}| 1334|           307|307|         Manufactura|
# | {JobSubcategory:75}| 1333|            75| 75|   Auxiliar contable|
# +--------------------+-----+--------------+---+--------------------+
# only showing top 25 rows

# %%
split_col = F.split(df["subcategory.__ref"].cast("String"), ":")
subcat_count_redir = df.withColumn("subcategory_id", split_col.getItem(1).cast("INT"))
subcat_count_redir = subcat_count_redir.groupby("subcategory_id").pivot("redirect.type").count()
subcat_count_redir = subcat_count_redir.join(subcategories.select("id", "description"), subcat_count_redir.subcategory_id == subcategories.id, how="inner")
subcat_count_redir = subcat_count_redir.select(["description", "0", "1", "2"]).sort(F.col("0").desc()).toPandas().fillna(0)
subcat_count_redir.columns = ["subcategory", "NoRedir", "Redir1", "Redir2(AGG)"]
subcat_count_redir = subcat_count_redir.set_index("subcategory")
subcat_count_redir = subcat_count_redir.div(subcat_count_redir.sum(axis=1), axis=0)
pd.set_option('display.max_rows', None)
subcat_count_redir
# Out:
#                                                NoRedir    Redir1  Redir2(AGG)
# subcategory
# Ventas en general                             0.570386  0.046221     0.383393
# Contabilidad                                  0.787839  0.010461     0.201700
# Administración de ventas                      0.641499  0.039193     0.319308
# Atención al cliente                           0.347131  0.020528     0.632341
# Administración                                0.212324  0.009969     0.777707
# Ventas de campo                               0.621122  0.036666     0.342212
# Almacén - Inventario                          0.417959  0.011756     0.570285
# Reclutamiento y selección de personal         0.789274  0.019459     0.191267
# Desarrollo de software - Programador          0.408648  0.069733     0.521620
# Crédito y cobranza                            0.418911  0.018666     0.562424
# Administración de proyectos                   0.702570  0.050184     0.247246
# Ventas corporativas                           0.712759  0.032684     0.254557
# Auxiliar administrativo                       0.631455  0.019953     0.348592
# Logística                                     0.826635  0.016548     0.156816
# Administración de personal                    0.955195  0.015253     0.029552
# Representante de ventas                       0.767669  0.019496     0.212835
# Soporte técnico                               0.567551  0.020507     0.411942
# Abastecimiento                                0.801364  0.015345     0.183291
# Auxiliar contable                             0.694674  0.003751     0.301575
# Comercial                                     0.731045  0.036712     0.232243
# Venta al detalle - Retail                     0.572445  0.051100     0.376455
# Manufactura                                   0.634933  0.026237     0.338831
# Administración de oficina                     0.874477  0.030335     0.095188
# Administración de operaciones                 0.753650  0.013686     0.232664
# Control de Calidad                            0.422414  0.013470     0.564116
# Compras                                       0.542361  0.011806     0.445833
# Comercio Exterior - Importación -Exportación  0.759568  0.008832     0.231600
# Mantenimiento general                         0.462805  0.009146     0.528049
# Call center                                   0.926561  0.035496     0.037944
# Ingeniero                                     0.773101  0.024641     0.202259
# Ingeniería industrial                         0.510402  0.027046     0.462552
# Ventas por teléfono - Telemarketing           0.675755  0.015579     0.308666
# Ventas de piso                                0.659962  0.011494     0.328544
# Mercadotecnia                                 0.603006  0.021220     0.375774
# Operaciones                                   0.479018  0.022169     0.498812
# Administración de obra                        0.846041  0.013196     0.140762
# Automatización                                0.788966  0.041379     0.169655
# Seguridad                                     0.357369  0.008223     0.634409
# Asesoría comercial                            0.545187  0.026523     0.428291
# Medicina general                              0.806854  0.007788     0.185358
# Finanzas                                      0.730226  0.111582     0.158192
# Chofer                                        0.349831  0.001356     0.648814
# Ventas Técnicas                               0.644110  0.040100     0.315789
# Redes - Telecomunicaciones                    0.587486  0.016222     0.396292
# Desarrollo de negocios                        0.447653  0.050542     0.501805
# Maestro - Docente - Profesor                  0.648755  0.006553     0.344692
# Auditoría                                     0.698413  0.012987     0.288600
# Farmacéutica                                  0.711278  0.039098     0.249624
# Consultoría TI                                0.590561  0.015306     0.394133
# Impuestos                                     0.705512  0.018898     0.275591
# Embarque y distribución                       0.656012  0.018265     0.325723
# Servicios generales                           0.560106  0.088507     0.351387
# Servicio                                      0.884211  0.025263     0.090526
# Construcción                                  0.945455  0.015909     0.038636
# Informática                                   0.605655  0.032738     0.361607
# Base de datos                                 0.610942  0.028875     0.360182
# Promotor - Demostradoras                      0.256887  0.027546     0.715567
# Ingeniería civil                              0.809917  0.014463     0.175620
# Actuaría                                      0.878104  0.060948     0.060948
# Banca                                         0.718574  0.138837     0.142589
# Recepción y operación                         0.699262  0.018450     0.282288
# Mantenimiento mecánico                        0.594340  0.014151     0.391509
# Capacitación y desarrollo                     0.596491  0.054226     0.349282
# Seguridad informática                         0.561644  0.057839     0.380518
# Control de producción                         0.443489  0.015971     0.540541
# Distribución                                  0.797297  0.020270     0.182432
# Ingeniería automotriz                         0.620141  0.031802     0.348057
# Administrador de sistemas                     0.508029  0.036496     0.455474
# Ingeniería mecánica                           0.672165  0.037113     0.290722
# Marketing digital                             0.836788  0.002591     0.160622
# Nómina                                        0.865922  0.008380     0.125698
# Desarrollo web                                0.592664  0.011583     0.395753
# Cuentas por pagar                             0.646186  0.027542     0.326271
# Enfermería                                    0.725301  0.019277     0.255422
# Ingeniería de mantenimiento                   0.552486  0.016575     0.430939
# Ventas de mayoreo                             0.524823  0.007092     0.468085
# SAP                                           0.561644  0.013699     0.424658
# Tráfico                                       0.685851  0.002398     0.311751
# Ingeniería de procesos                        0.662791  0.030233     0.306977
# Ventas de seguros - Reaseguros                0.710000  0.132500     0.157500
# Ingeniería electromecánica                    0.610738  0.008949     0.380313
# Ingeniería eléctrica                          0.543260  0.016097     0.440644
# Pruebas - Control de calidad                  0.436482  0.029316     0.534202
# Arquitecto                                    0.727778  0.016667     0.255556
# Ayudante general                              0.189616  0.016554     0.793830
# Diseño gráfico                                0.637975  0.000000     0.362025
# Restaurante - Bar                             0.447464  0.003623     0.548913
# Infraestructura                               0.631169  0.018182     0.350649
# Beneficios y compensaciones                   0.480084  0.012579     0.507338
# Derecho                                       0.770270  0.050676     0.179054
# Instalaciones e infraestructura               0.878906  0.031250     0.089844
# E-Commerce                                    0.906883  0.000000     0.093117
# Administración de proyectos                   0.742373  0.030508     0.227119
# Contabilidad de costos - Inventario           0.654434  0.015291     0.330275
# Ventas inmobiliarias                          0.482838  0.020595     0.496568
# Derecho corporativo                           0.800000  0.030769     0.169231
# Facturación                                   0.674576  0.006780     0.318644
# Planeación estratégica                        0.563050  0.032258     0.404692
# Dirección académica                           0.818182  0.000000     0.181818
# Análisis financiero - Pronóstico              0.484456  0.056995     0.458549
# Ventas por cambaceo                           0.530086  0.054441     0.415473
# Finanzas corporativas                         0.744939  0.052632     0.202429
# Especialidades médicas                        0.948187  0.000000     0.051813
# Agente de seguros                             0.938144  0.041237     0.020619
# Investigación de mercado                      0.694981  0.011583     0.293436
# Cajero                                        0.090769  0.032308     0.876923
# Ejecutivo empresarial banca                   0.339216  0.121569     0.539216
# Ingeniería electrónica                        0.618705  0.014388     0.366906
# Ingeniería química                            0.670588  0.011765     0.317647
# Tesorería                                     0.725322  0.030043     0.244635
# Técnico                                       0.877660  0.010638     0.111702
# Mantenimiento general                         0.976190  0.000000     0.023810
# Obra                                          0.865591  0.000000     0.134409
# Medicina laboral                              0.939394  0.012121     0.048485
# Hoteles                                       0.439655  0.002874     0.557471
# Relaciones laborales                          0.686364  0.027273     0.286364
# Gestión de seguros                            0.825137  0.163934     0.010929
# Mantenimiento eléctrico                       0.778378  0.021622     0.200000
# Cocina                                        0.284861  0.005976     0.709163
# Contraloría                                   0.572581  0.064516     0.362903
# Apoyo a ventas                                0.691176  0.098039     0.210784
# Siniestros                                    0.598291  0.324786     0.076923
# Alimentos y bebidas                           0.831325  0.030120     0.138554
# Ingeniería de datos                           0.637209  0.027907     0.334884
# Procesamiento de datos                        0.316397  0.036952     0.646651
# Analista de ventas                            0.336683  0.050251     0.613065
# Agencia de viajes                             0.796407  0.029940     0.173653
# Desarrollo organizacional                     0.891892  0.006757     0.101351
# Seguridad e higiene                           0.643564  0.004950     0.351485
# Asistente de dirección                        0.821656  0.070064     0.108280
# Residente de obra                             0.913043  0.000000     0.086957
# Comunicación e imagen                         0.730994  0.023392     0.245614
# Secretaria                                    0.490040  0.003984     0.505976
# Control de materiales                         0.435714  0.014286     0.550000
# Desarrollo de aplicaciones móviles            0.643243  0.021622     0.335135
# Ambulancia - Paramédicos                      0.842857  0.000000     0.157143
# Asesor financiero                             0.544186  0.013953     0.441860
# Laboratorio - Patología                       0.565854  0.014634     0.419512
# Mantenimiento automotríz                      0.748344  0.000000     0.251656
# Soporte                                       0.918033  0.040984     0.040984
# Idiomas                                       0.711538  0.000000     0.288462
# Arquitecto de soluciones                      0.658683  0.029940     0.311377
# Actuario                                      0.756944  0.187500     0.055556
# Producto                                      0.618497  0.075145     0.306358
# Gestión de flotas                             0.726027  0.013699     0.260274
# Turismo                                       0.706667  0.000000     0.293333
# Aduana                                        0.410156  0.003906     0.585938
# Relaciones públicas                           0.772727  0.037879     0.189394
# Ingeniería en alimentos                       0.879310  0.043103     0.077586
# Innovación y desarrollo de productos          0.594118  0.058824     0.347059
# Derecho mercantil                             0.833333  0.033333     0.133333
# Agronomía y granja                            0.793651  0.031746     0.174603
# Mensajería                                    0.489899  0.000000     0.510101
# Otros oficios                                 0.375000  0.394531     0.230469
# Post venta                                    0.869159  0.046729     0.084112
# Inyección de plásticos                        0.564417  0.006135     0.429448
# Mantenimiento electrónico                     0.429245  0.009434     0.561321
# Diseñador industrial                          0.833333  0.055556     0.111111
# Diseño de interiores                          0.565789  0.065789     0.368421
# Derecho laboral                               0.895833  0.000000     0.104167
# Ingeniería de planta                          0.525000  0.075000     0.400000
# Administración de riesgo                      0.638462  0.176923     0.184615
# Máquinas y herramientas                       0.400000  0.014634     0.585366
# Planeación financiera                         0.535948  0.071895     0.392157
# Radiología                                    1.000000  0.000000     0.000000
# Jefe de piso                                  0.764151  0.009434     0.226415
# Servicios estudiantiles                       0.975610  0.000000     0.024390
# Mercados financieros - Inversión              0.506410  0.057692     0.435897
# Big data                                      0.802083  0.010417     0.187500
# Diseño web - Digital                          0.892857  0.047619     0.059524
# Chef                                          0.580645  0.000000     0.419355
# Ingeniería ambiental                          0.800000  0.011111     0.188889
# Petróleo y energía                            0.946667  0.000000     0.053333
# Publicidad                                    0.710000  0.010000     0.280000
# Archivista y manejo de documentación          0.612069  0.060345     0.327586
# Suscripción - Seguros                         0.772727  0.125000     0.102273
# Diseño mecánico                               0.572650  0.042735     0.384615
# Organización de eventos                       0.747126  0.000000     0.252874
# Científico de datos                           0.927536  0.000000     0.072464
# Administración de seguros y fianzas           0.923077  0.030769     0.046154
# Odontología y especialidades                  0.743590  0.025641     0.230769
# Derecho inmobiliario                          0.966102  0.000000     0.033898
# Limpieza                                      0.204301  0.000000     0.795699
# Instructor - Capacitador                      1.000000  0.000000     0.000000
# Animación digital                             0.903226  0.032258     0.064516
# Operador de CNC                               0.568421  0.000000     0.431579
# Moda y diseño textil                          0.760563  0.000000     0.239437
# Creatividad y diseño                          1.000000  0.000000     0.000000
# E- Business                                   0.356643  0.041958     0.601399
# Capturista                                    0.877193  0.017544     0.105263
# Valuador - Joyero                             0.187739  0.000000     0.812261
# Innovación y desarrollo                       0.505155  0.020619     0.474227
# Transporte aéreo                              0.761905  0.015873     0.222222
# Planeación de medios                          0.480000  0.000000     0.520000
# Producción audiovisual y digital              0.592593  0.000000     0.407407
# Eventos - Banquetes - Convenciones            0.774194  0.080645     0.145161
# Operador de tractocamión                      0.623377  0.012987     0.363636
# Diseño de producto                            0.960000  0.000000     0.040000
# Economía                                      0.824561  0.087719     0.087719
# Montacargas                                   0.979167  0.020833     0.000000
# Administración de inmuebles y activos fijos   0.647059  0.029412     0.323529
# Entrenador personal                           0.758621  0.017241     0.224138
# Edición de contenido                          0.651515  0.000000     0.348485
# Médico veterinario                            0.728814  0.000000     0.271186
# Urbanismo                                     0.716667  0.083333     0.200000
# Soporte de ventas                             0.215789  0.005263     0.778947
# Consultoría                                   0.745455  0.036364     0.218182
# Medios de comunicación                        0.909091  0.000000     0.090909
# Psicopedagogía                                0.795918  0.000000     0.204082
# Robótica- Mecatrónica - Nanotecnología        0.883721  0.000000     0.116279
# Spa                                           0.622951  0.000000     0.377049
# Optometrista                                  0.692308  0.000000     0.307692
# Psicología                                    0.800000  0.022222     0.177778
# Ingeniero agrónomo                            0.734694  0.102041     0.163265
# Nutrición                                     0.660377  0.000000     0.339623
# Criminalística                                0.921053  0.052632     0.026316
# Preventa                                      0.333333  0.019048     0.647619
# Derecho penal                                 0.842105  0.000000     0.157895
# Transporte ferroviario y marítimo             0.659574  0.000000     0.340426
# Artes gráficas                                0.810811  0.000000     0.189189
# Derecho fiscal                                0.666667  0.022222     0.311111
# Social media                                  0.566038  0.000000     0.433962
# Corredor de seguros y reaseguros              0.966667  0.000000     0.033333
# Chofer ejecutivo                              0.964286  0.035714     0.000000
# Maquinaria pesada - Operador                  0.870968  0.000000     0.129032
# Terapeuta                                     0.818182  0.000000     0.181818
# Asesor contable                               0.838710  0.032258     0.129032
# Chofer                                        0.962963  0.037037     0.000000
# Arte creativo                                 0.735294  0.058824     0.205882
# Investigación clínica - Médica                0.960000  0.000000     0.040000
# Ingeniería en aeronáutica - Aeroespacial      0.600000  0.100000     0.300000
# Hojalatería y pintura                         0.383333  0.000000     0.616667
# Derecho civil                                 1.000000  0.000000     0.000000
# Emisión seguros                               0.696970  0.121212     0.181818
# Periodismo                                    0.511628  0.000000     0.488372
# UX - UI                                       0.913043  0.043478     0.043478
# Producción audiovisual                        0.456522  0.065217     0.478261
# Fisioterapia y rehabilitación                 0.807692  0.000000     0.192308
# Ajustador                                     0.500000  0.475000     0.025000
# Química                                       1.000000  0.000000     0.000000
# Recepcionista                                 0.512821  0.000000     0.487179
# Ingeniero en minas                            0.950000  0.000000     0.050000
# Agronomía                                     1.000000  0.000000     0.000000
# Camarista                                     0.115385  0.000000     0.884615
# Capacitación en TI                            0.300000  0.000000     0.700000
# Estilismo                                     0.629630  0.000000     0.370370
# Educación física                              0.653846  0.000000     0.346154
# Metrología                                    0.850000  0.000000     0.150000
# Ingeniería en metalurgia                      0.548387  0.000000     0.451613
# Ensamblador                                   0.944444  0.000000     0.055556
# Auditoría Interna                             0.850000  0.100000     0.050000
# Ingeniería textil                             0.472222  0.027778     0.500000
# Colorista - Igualador                         0.842105  0.000000     0.157895
# Ingeniería en materiales                      0.432432  0.027027     0.540541
# Ingeniería en desarrollo sustentable          0.172414  0.000000     0.827586
# Derecho notarial                              0.600000  0.080000     0.320000
# Recursos naturales                            1.000000  0.000000     0.000000
# Concierge                                     0.388889  0.000000     0.611111
# Flebotomía                                    0.823529  0.058824     0.117647
# Educación especial                            1.000000  0.000000     0.000000
# Operador de autobús                           1.000000  0.000000     0.000000
# Consultoría ambiental                         0.565217  0.000000     0.434783
# Inteligencia artificial                       0.276596  0.021277     0.702128
# Editor                                        0.520000  0.000000     0.480000
# Cocina, bar y cafetería                       1.000000  0.000000     0.000000
# Mensajero                                     1.000000  0.000000     0.000000
# Coordinación de grupos                        0.687500  0.000000     0.312500
# Entretenimiento                               1.000000  0.000000     0.000000
# Decoración                                    1.000000  0.000000     0.000000
# Laboratorista automotriz                      1.000000  0.000000     0.000000
# Desarrollo sustentable                        1.000000  0.000000     0.000000
# Traducción                                    0.750000  0.000000     0.250000
# Otros                                         1.000000  0.000000     0.000000
# Dibujo técnico                                0.600000  0.000000     0.400000
# Asesoría legal de seguros                     0.727273  0.090909     0.181818
# Humanidades                                   1.000000  0.000000     0.000000
# Técnico especialista en motores gas - Diesel  0.875000  0.000000     0.125000
# Capitán                                       0.636364  0.000000     0.363636
# Fotografía                                    0.583333  0.000000     0.416667
# Diseño editorial                              1.000000  0.000000     0.000000
# Intérprete                                    1.000000  0.000000     0.000000
# Geólogo                                       0.600000  0.000000     0.400000
# Lavandería                                    0.150000  0.000000     0.850000
# Trabajo social                                0.500000  0.083333     0.416667
# Manicurista                                   0.375000  0.062500     0.562500
# Arte y cultura                                0.714286  0.000000     0.285714
# Petroquímica                                  1.000000  0.000000     0.000000
# Estética canina                               0.625000  0.000000     0.375000
# Guía de turismo                               0.833333  0.000000     0.166667
# Makeup artist                                 1.000000  0.000000     0.000000
# Operador de campo                             0.833333  0.000000     0.166667
# Ecología                                      1.000000  0.000000     0.000000
# Cinematografía                                1.000000  0.000000     0.000000
# Mesero                                        0.066667  0.000000     0.933333
# Masajista                                     0.666667  0.000000     0.333333
# Sociología                                    1.000000  0.000000     0.000000
# Derecho minero y energético                   1.000000  0.000000     0.000000
# Medicina del deporte                          1.000000  0.000000     0.000000
# Geografía                                     1.000000  0.000000     0.000000
# Medicina alternativa                          1.000000  0.000000     0.000000
# Derecho ambiental                             1.000000  0.000000     0.000000
# Ingeniería física                             1.000000  0.000000     0.000000
# Médico legista                                1.000000  0.000000     0.000000
# Hostess                                       1.000000  0.000000     0.000000
# Topografía                                    1.000000  0.000000     0.000000
# Política                                      1.000000  0.000000     0.000000
# Supervisor de mina                            0.666667  0.333333     0.000000
# Lingüística                                   1.000000  0.000000     0.000000
# Investigación y desarrollo                    0.400000  0.400000     0.200000
# Asistente médico                              1.000000  0.000000     0.000000
# Biotecnología                                 0.071429  0.000000     0.928571
# Biología                                      0.500000  0.000000     0.500000
# Seguridad ciudadana                           1.000000  0.000000     0.000000
# Matemáticas                                   1.000000  0.000000     0.000000
# Música                                        0.090909  0.000000     0.909091
# Riesgos                                       1.000000  0.000000     0.000000
# Operadores de maquinaria                      0.500000  0.500000     0.000000
# Pesca y acuicultura                           1.000000  0.000000     0.000000
# Artes escénicas                               1.000000  0.000000     0.000000
# Ilustración                                   0.000000  0.000000     1.000000
# Taquillero                                    0.000000  0.000000     1.000000
# Plataformas                                   0.000000  0.000000     1.000000
# Ingeniería genética                           0.000000  0.000000     1.000000
# Pedicurista                                   0.000000  0.000000     1.000000
# Hipoteca                                      0.000000  0.500000     0.500000
#                                               0.000000  0.000000     1.000000

# %%
subcat_count_redir.sort_values("Redir2(AGG)", ascending=False)
# Out:
#                                                NoRedir    Redir1  Redir2(AGG)
# subcategory
#                                               0.000000  0.000000     1.000000
# Ingeniería genética                           0.000000  0.000000     1.000000
# Ilustración                                   0.000000  0.000000     1.000000
# Taquillero                                    0.000000  0.000000     1.000000
# Plataformas                                   0.000000  0.000000     1.000000
# Pedicurista                                   0.000000  0.000000     1.000000
# Mesero                                        0.066667  0.000000     0.933333
# Biotecnología                                 0.071429  0.000000     0.928571
# Música                                        0.090909  0.000000     0.909091
# Camarista                                     0.115385  0.000000     0.884615
# Cajero                                        0.090769  0.032308     0.876923
# Lavandería                                    0.150000  0.000000     0.850000
# Ingeniería en desarrollo sustentable          0.172414  0.000000     0.827586
# Valuador - Joyero                             0.187739  0.000000     0.812261
# Limpieza                                      0.204301  0.000000     0.795699
# Ayudante general                              0.189616  0.016554     0.793830
# Soporte de ventas                             0.215789  0.005263     0.778947
# Administración                                0.212324  0.009969     0.777707
# Promotor - Demostradoras                      0.256887  0.027546     0.715567
# Cocina                                        0.284861  0.005976     0.709163
# Inteligencia artificial                       0.276596  0.021277     0.702128
# Capacitación en TI                            0.300000  0.000000     0.700000
# Chofer                                        0.349831  0.001356     0.648814
# Preventa                                      0.333333  0.019048     0.647619
# Procesamiento de datos                        0.316397  0.036952     0.646651
# Seguridad                                     0.357369  0.008223     0.634409
# Atención al cliente                           0.347131  0.020528     0.632341
# Hojalatería y pintura                         0.383333  0.000000     0.616667
# Analista de ventas                            0.336683  0.050251     0.613065
# Concierge                                     0.388889  0.000000     0.611111
# E- Business                                   0.356643  0.041958     0.601399
# Aduana                                        0.410156  0.003906     0.585938
# Máquinas y herramientas                       0.400000  0.014634     0.585366
# Almacén - Inventario                          0.417959  0.011756     0.570285
# Control de Calidad                            0.422414  0.013470     0.564116
# Manicurista                                   0.375000  0.062500     0.562500
# Crédito y cobranza                            0.418911  0.018666     0.562424
# Mantenimiento electrónico                     0.429245  0.009434     0.561321
# Hoteles                                       0.439655  0.002874     0.557471
# Control de materiales                         0.435714  0.014286     0.550000
# Restaurante - Bar                             0.447464  0.003623     0.548913
# Ingeniería en materiales                      0.432432  0.027027     0.540541
# Control de producción                         0.443489  0.015971     0.540541
# Ejecutivo empresarial banca                   0.339216  0.121569     0.539216
# Pruebas - Control de calidad                  0.436482  0.029316     0.534202
# Mantenimiento general                         0.462805  0.009146     0.528049
# Desarrollo de software - Programador          0.408648  0.069733     0.521620
# Planeación de medios                          0.480000  0.000000     0.520000
# Mensajería                                    0.489899  0.000000     0.510101
# Beneficios y compensaciones                   0.480084  0.012579     0.507338
# Secretaria                                    0.490040  0.003984     0.505976
# Desarrollo de negocios                        0.447653  0.050542     0.501805
# Hipoteca                                      0.000000  0.500000     0.500000
# Ingeniería textil                             0.472222  0.027778     0.500000
# Biología                                      0.500000  0.000000     0.500000
# Operaciones                                   0.479018  0.022169     0.498812
# Ventas inmobiliarias                          0.482838  0.020595     0.496568
# Periodismo                                    0.511628  0.000000     0.488372
# Recepcionista                                 0.512821  0.000000     0.487179
# Editor                                        0.520000  0.000000     0.480000
# Producción audiovisual                        0.456522  0.065217     0.478261
# Innovación y desarrollo                       0.505155  0.020619     0.474227
# Ventas de mayoreo                             0.524823  0.007092     0.468085
# Ingeniería industrial                         0.510402  0.027046     0.462552
# Análisis financiero - Pronóstico              0.484456  0.056995     0.458549
# Administrador de sistemas                     0.508029  0.036496     0.455474
# Ingeniería en metalurgia                      0.548387  0.000000     0.451613
# Compras                                       0.542361  0.011806     0.445833
# Asesor financiero                             0.544186  0.013953     0.441860
# Ingeniería eléctrica                          0.543260  0.016097     0.440644
# Mercados financieros - Inversión              0.506410  0.057692     0.435897
# Consultoría ambiental                         0.565217  0.000000     0.434783
# Social media                                  0.566038  0.000000     0.433962
# Operador de CNC                               0.568421  0.000000     0.431579
# Ingeniería de mantenimiento                   0.552486  0.016575     0.430939
# Inyección de plásticos                        0.564417  0.006135     0.429448
# Asesoría comercial                            0.545187  0.026523     0.428291
# SAP                                           0.561644  0.013699     0.424658
# Laboratorio - Patología                       0.565854  0.014634     0.419512
# Chef                                          0.580645  0.000000     0.419355
# Fotografía                                    0.583333  0.000000     0.416667
# Trabajo social                                0.500000  0.083333     0.416667
# Ventas por cambaceo                           0.530086  0.054441     0.415473
# Soporte técnico                               0.567551  0.020507     0.411942
# Producción audiovisual y digital              0.592593  0.000000     0.407407
# Planeación estratégica                        0.563050  0.032258     0.404692
# Dibujo técnico                                0.600000  0.000000     0.400000
# Geólogo                                       0.600000  0.000000     0.400000
# Ingeniería de planta                          0.525000  0.075000     0.400000
# Redes - Telecomunicaciones                    0.587486  0.016222     0.396292
# Desarrollo web                                0.592664  0.011583     0.395753
# Consultoría TI                                0.590561  0.015306     0.394133
# Planeación financiera                         0.535948  0.071895     0.392157
# Mantenimiento mecánico                        0.594340  0.014151     0.391509
# Diseño mecánico                               0.572650  0.042735     0.384615
# Ventas en general                             0.570386  0.046221     0.383393
# Seguridad informática                         0.561644  0.057839     0.380518
# Ingeniería electromecánica                    0.610738  0.008949     0.380313
# Spa                                           0.622951  0.000000     0.377049
# Venta al detalle - Retail                     0.572445  0.051100     0.376455
# Mercadotecnia                                 0.603006  0.021220     0.375774
# Estética canina                               0.625000  0.000000     0.375000
# Estilismo                                     0.629630  0.000000     0.370370
# Diseño de interiores                          0.565789  0.065789     0.368421
# Ingeniería electrónica                        0.618705  0.014388     0.366906
# Capitán                                       0.636364  0.000000     0.363636
# Operador de tractocamión                      0.623377  0.012987     0.363636
# Contraloría                                   0.572581  0.064516     0.362903
# Diseño gráfico                                0.637975  0.000000     0.362025
# Informática                                   0.605655  0.032738     0.361607
# Base de datos                                 0.610942  0.028875     0.360182
# Seguridad e higiene                           0.643564  0.004950     0.351485
# Servicios generales                           0.560106  0.088507     0.351387
# Infraestructura                               0.631169  0.018182     0.350649
# Capacitación y desarrollo                     0.596491  0.054226     0.349282
# Auxiliar administrativo                       0.631455  0.019953     0.348592
# Edición de contenido                          0.651515  0.000000     0.348485
# Ingeniería automotriz                         0.620141  0.031802     0.348057
# Innovación y desarrollo de productos          0.594118  0.058824     0.347059
# Educación física                              0.653846  0.000000     0.346154
# Maestro - Docente - Profesor                  0.648755  0.006553     0.344692
# Ventas de campo                               0.621122  0.036666     0.342212
# Transporte ferroviario y marítimo             0.659574  0.000000     0.340426
# Nutrición                                     0.660377  0.000000     0.339623
# Manufactura                                   0.634933  0.026237     0.338831
# Desarrollo de aplicaciones móviles            0.643243  0.021622     0.335135
# Ingeniería de datos                           0.637209  0.027907     0.334884
# Masajista                                     0.666667  0.000000     0.333333
# Contabilidad de costos - Inventario           0.654434  0.015291     0.330275
# Ventas de piso                                0.659962  0.011494     0.328544
# Archivista y manejo de documentación          0.612069  0.060345     0.327586
# Cuentas por pagar                             0.646186  0.027542     0.326271
# Embarque y distribución                       0.656012  0.018265     0.325723
# Administración de inmuebles y activos fijos   0.647059  0.029412     0.323529
# Derecho notarial                              0.600000  0.080000     0.320000
# Administración de ventas                      0.641499  0.039193     0.319308
# Facturación                                   0.674576  0.006780     0.318644
# Ingeniería química                            0.670588  0.011765     0.317647
# Ventas Técnicas                               0.644110  0.040100     0.315789
# Coordinación de grupos                        0.687500  0.000000     0.312500
# Tráfico                                       0.685851  0.002398     0.311751
# Arquitecto de soluciones                      0.658683  0.029940     0.311377
# Derecho fiscal                                0.666667  0.022222     0.311111
# Ventas por teléfono - Telemarketing           0.675755  0.015579     0.308666
# Optometrista                                  0.692308  0.000000     0.307692
# Ingeniería de procesos                        0.662791  0.030233     0.306977
# Producto                                      0.618497  0.075145     0.306358
# Auxiliar contable                             0.694674  0.003751     0.301575
# Ingeniería en aeronáutica - Aeroespacial      0.600000  0.100000     0.300000
# Investigación de mercado                      0.694981  0.011583     0.293436
# Turismo                                       0.706667  0.000000     0.293333
# Ingeniería mecánica                           0.672165  0.037113     0.290722
# Auditoría                                     0.698413  0.012987     0.288600
# Idiomas                                       0.711538  0.000000     0.288462
# Relaciones laborales                          0.686364  0.027273     0.286364
# Arte y cultura                                0.714286  0.000000     0.285714
# Recepción y operación                         0.699262  0.018450     0.282288
# Publicidad                                    0.710000  0.010000     0.280000
# Impuestos                                     0.705512  0.018898     0.275591
# Médico veterinario                            0.728814  0.000000     0.271186
# Gestión de flotas                             0.726027  0.013699     0.260274
# Arquitecto                                    0.727778  0.016667     0.255556
# Enfermería                                    0.725301  0.019277     0.255422
# Ventas corporativas                           0.712759  0.032684     0.254557
# Organización de eventos                       0.747126  0.000000     0.252874
# Mantenimiento automotríz                      0.748344  0.000000     0.251656
# Traducción                                    0.750000  0.000000     0.250000
# Farmacéutica                                  0.711278  0.039098     0.249624
# Administración de proyectos                   0.702570  0.050184     0.247246
# Comunicación e imagen                         0.730994  0.023392     0.245614
# Tesorería                                     0.725322  0.030043     0.244635
# Moda y diseño textil                          0.760563  0.000000     0.239437
# Administración de operaciones                 0.753650  0.013686     0.232664
# Comercial                                     0.731045  0.036712     0.232243
# Comercio Exterior - Importación -Exportación  0.759568  0.008832     0.231600
# Odontología y especialidades                  0.743590  0.025641     0.230769
# Otros oficios                                 0.375000  0.394531     0.230469
# Administración de proyectos                   0.742373  0.030508     0.227119
# Jefe de piso                                  0.764151  0.009434     0.226415
# Entrenador personal                           0.758621  0.017241     0.224138
# Transporte aéreo                              0.761905  0.015873     0.222222
# Consultoría                                   0.745455  0.036364     0.218182
# Representante de ventas                       0.767669  0.019496     0.212835
# Apoyo a ventas                                0.691176  0.098039     0.210784
# Arte creativo                                 0.735294  0.058824     0.205882
# Psicopedagogía                                0.795918  0.000000     0.204082
# Finanzas corporativas                         0.744939  0.052632     0.202429
# Ingeniero                                     0.773101  0.024641     0.202259
# Contabilidad                                  0.787839  0.010461     0.201700
# Investigación y desarrollo                    0.400000  0.400000     0.200000
# Mantenimiento eléctrico                       0.778378  0.021622     0.200000
# Urbanismo                                     0.716667  0.083333     0.200000
# Fisioterapia y rehabilitación                 0.807692  0.000000     0.192308
# Reclutamiento y selección de personal         0.789274  0.019459     0.191267
# Relaciones públicas                           0.772727  0.037879     0.189394
# Artes gráficas                                0.810811  0.000000     0.189189
# Ingeniería ambiental                          0.800000  0.011111     0.188889
# Big data                                      0.802083  0.010417     0.187500
# Medicina general                              0.806854  0.007788     0.185358
# Administración de riesgo                      0.638462  0.176923     0.184615
# Abastecimiento                                0.801364  0.015345     0.183291
# Distribución                                  0.797297  0.020270     0.182432
# Emisión seguros                               0.696970  0.121212     0.181818
# Terapeuta                                     0.818182  0.000000     0.181818
# Asesoría legal de seguros                     0.727273  0.090909     0.181818
# Dirección académica                           0.818182  0.000000     0.181818
# Derecho                                       0.770270  0.050676     0.179054
# Psicología                                    0.800000  0.022222     0.177778
# Ingeniería civil                              0.809917  0.014463     0.175620
# Agronomía y granja                            0.793651  0.031746     0.174603
# Agencia de viajes                             0.796407  0.029940     0.173653
# Automatización                                0.788966  0.041379     0.169655
# Derecho corporativo                           0.800000  0.030769     0.169231
# Operador de campo                             0.833333  0.000000     0.166667
# Guía de turismo                               0.833333  0.000000     0.166667
# Ingeniero agrónomo                            0.734694  0.102041     0.163265
# Marketing digital                             0.836788  0.002591     0.160622
# Finanzas                                      0.730226  0.111582     0.158192
# Colorista - Igualador                         0.842105  0.000000     0.157895
# Derecho penal                                 0.842105  0.000000     0.157895
# Ventas de seguros - Reaseguros                0.710000  0.132500     0.157500
# Ambulancia - Paramédicos                      0.842857  0.000000     0.157143
# Logística                                     0.826635  0.016548     0.156816
# Metrología                                    0.850000  0.000000     0.150000
# Eventos - Banquetes - Convenciones            0.774194  0.080645     0.145161
# Banca                                         0.718574  0.138837     0.142589
# Administración de obra                        0.846041  0.013196     0.140762
# Alimentos y bebidas                           0.831325  0.030120     0.138554
# Obra                                          0.865591  0.000000     0.134409
# Derecho mercantil                             0.833333  0.033333     0.133333
# Asesor contable                               0.838710  0.032258     0.129032
# Maquinaria pesada - Operador                  0.870968  0.000000     0.129032
# Nómina                                        0.865922  0.008380     0.125698
# Técnico especialista en motores gas - Diesel  0.875000  0.000000     0.125000
# Flebotomía                                    0.823529  0.058824     0.117647
# Robótica- Mecatrónica - Nanotecnología        0.883721  0.000000     0.116279
# Técnico                                       0.877660  0.010638     0.111702
# Diseñador industrial                          0.833333  0.055556     0.111111
# Asistente de dirección                        0.821656  0.070064     0.108280
# Capturista                                    0.877193  0.017544     0.105263
# Derecho laboral                               0.895833  0.000000     0.104167
# Suscripción - Seguros                         0.772727  0.125000     0.102273
# Desarrollo organizacional                     0.891892  0.006757     0.101351
# Administración de oficina                     0.874477  0.030335     0.095188
# E-Commerce                                    0.906883  0.000000     0.093117
# Medios de comunicación                        0.909091  0.000000     0.090909
# Servicio                                      0.884211  0.025263     0.090526
# Instalaciones e infraestructura               0.878906  0.031250     0.089844
# Economía                                      0.824561  0.087719     0.087719
# Residente de obra                             0.913043  0.000000     0.086957
# Post venta                                    0.869159  0.046729     0.084112
# Ingeniería en alimentos                       0.879310  0.043103     0.077586
# Siniestros                                    0.598291  0.324786     0.076923
# Científico de datos                           0.927536  0.000000     0.072464
# Animación digital                             0.903226  0.032258     0.064516
# Actuaría                                      0.878104  0.060948     0.060948
# Diseño web - Digital                          0.892857  0.047619     0.059524
# Ensamblador                                   0.944444  0.000000     0.055556
# Actuario                                      0.756944  0.187500     0.055556
# Petróleo y energía                            0.946667  0.000000     0.053333
# Especialidades médicas                        0.948187  0.000000     0.051813
# Ingeniero en minas                            0.950000  0.000000     0.050000
# Auditoría Interna                             0.850000  0.100000     0.050000
# Medicina laboral                              0.939394  0.012121     0.048485
# Administración de seguros y fianzas           0.923077  0.030769     0.046154
# UX - UI                                       0.913043  0.043478     0.043478
# Soporte                                       0.918033  0.040984     0.040984
# Diseño de producto                            0.960000  0.000000     0.040000
# Investigación clínica - Médica                0.960000  0.000000     0.040000
# Construcción                                  0.945455  0.015909     0.038636
# Call center                                   0.926561  0.035496     0.037944
# Derecho inmobiliario                          0.966102  0.000000     0.033898
# Corredor de seguros y reaseguros              0.966667  0.000000     0.033333
# Administración de personal                    0.955195  0.015253     0.029552
# Criminalística                                0.921053  0.052632     0.026316
# Ajustador                                     0.500000  0.475000     0.025000
# Servicios estudiantiles                       0.975610  0.000000     0.024390
# Mantenimiento general                         0.976190  0.000000     0.023810
# Agente de seguros                             0.938144  0.041237     0.020619
# Gestión de seguros                            0.825137  0.163934     0.010929
# Ingeniería física                             1.000000  0.000000     0.000000
# Derecho ambiental                             1.000000  0.000000     0.000000
# Topografía                                    1.000000  0.000000     0.000000
# Política                                      1.000000  0.000000     0.000000
# Médico legista                                1.000000  0.000000     0.000000
# Hostess                                       1.000000  0.000000     0.000000
# Radiología                                    1.000000  0.000000     0.000000
# Supervisor de mina                            0.666667  0.333333     0.000000
# Lingüística                                   1.000000  0.000000     0.000000
# Asistente médico                              1.000000  0.000000     0.000000
# Seguridad ciudadana                           1.000000  0.000000     0.000000
# Matemáticas                                   1.000000  0.000000     0.000000
# Geografía                                     1.000000  0.000000     0.000000
# Riesgos                                       1.000000  0.000000     0.000000
# Operadores de maquinaria                      0.500000  0.500000     0.000000
# Pesca y acuicultura                           1.000000  0.000000     0.000000
# Artes escénicas                               1.000000  0.000000     0.000000
# Medicina alternativa                          1.000000  0.000000     0.000000
# Química                                       1.000000  0.000000     0.000000
# Medicina del deporte                          1.000000  0.000000     0.000000
# Laboratorista automotriz                      1.000000  0.000000     0.000000
# Agronomía                                     1.000000  0.000000     0.000000
# Derecho civil                                 1.000000  0.000000     0.000000
# Chofer ejecutivo                              0.964286  0.035714     0.000000
# Recursos naturales                            1.000000  0.000000     0.000000
# Montacargas                                   0.979167  0.020833     0.000000
# Educación especial                            1.000000  0.000000     0.000000
# Operador de autobús                           1.000000  0.000000     0.000000
# Cocina, bar y cafetería                       1.000000  0.000000     0.000000
# Mensajero                                     1.000000  0.000000     0.000000
# Entretenimiento                               1.000000  0.000000     0.000000
# Decoración                                    1.000000  0.000000     0.000000
# Desarrollo sustentable                        1.000000  0.000000     0.000000
# Derecho minero y energético                   1.000000  0.000000     0.000000
# Otros                                         1.000000  0.000000     0.000000
# Humanidades                                   1.000000  0.000000     0.000000
# Creatividad y diseño                          1.000000  0.000000     0.000000
# Diseño editorial                              1.000000  0.000000     0.000000
# Intérprete                                    1.000000  0.000000     0.000000
# Instructor - Capacitador                      1.000000  0.000000     0.000000
# Petroquímica                                  1.000000  0.000000     0.000000
# Makeup artist                                 1.000000  0.000000     0.000000
# Ecología                                      1.000000  0.000000     0.000000
# Cinematografía                                1.000000  0.000000     0.000000
# Sociología                                    1.000000  0.000000     0.000000
# Chofer                                        0.962963  0.037037     0.000000

# %%
df.groupby("googleForJobs").count().sort(F.col("count").desc()).show(truncate=False)
# Out:
# +-----------------------------+------+
# |googleForJobs                |count |
# +-----------------------------+------+
# |{GoogleForJobs, true, true}  |135814|
# |{GoogleForJobs, false, false}|1470  |
# +-----------------------------+------+

# %%
subcategories.where("description = 'Flebotomía'").show(truncate=False)
# Out:
# +--------------+-----------+---+-------------------------------------------+
# |__typename    |description|id |url                                        |
# +--------------+-----------+---+-------------------------------------------+
# |JobSubcategory|Flebotomía |401|empleos/trabajo-en-sector-salud-flebotomia/|
# +--------------+-----------+---+-------------------------------------------+

# %%
company_count = df.groupby("company.url").count().sort(F.col("count").desc())
print(company_count.count())
company_count.show(truncate=False)
# Out:
# 14380
# +--------------------------------------------------+-----+
# |url                                               |count|
# +--------------------------------------------------+-----+
# |null                                              |16764|
# |empleos/bolsa-de-trabajo-Test-and-QA-Corporation/ |9207 |
# |empleos/bolsa-de-trabajo-grupo-salinas/           |7591 |
# |empleos/bolsa-de-trabajo-Un-Mejor-Empleo/         |3190 |
# |empleos/bolsa-de-trabajo-Trabajos-Diarios-MX/     |2985 |
# |empleos/bolsa-de-trabajo-Grupo-Salinas/           |1886 |
# |empleos/bolsa-de-trabajo-gepp/                    |1572 |
# |empleos/bolsa-de-trabajo-truper/                  |1452 |
# |empleos/bolsa-de-trabajo-Adecco/                  |952  |
# |empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/  |916  |
# |empleos/bolsa-de-trabajo-Banamex/                 |844  |
# |empleos/bolsa-de-trabajo-Santander/               |763  |
# |empleos/bolsa-de-trabajo-Autofinauto/             |710  |
# |empleos/bolsa-de-trabajo-CitiGroup/               |700  |
# |empleos/bolsa-de-trabajo-bairesdev/               |619  |
# |empleos/bolsa-de-trabajo-Banorte/                 |492  |
# |empleos/bolsa-de-trabajo-Workable-ATS/            |439  |
# |empleos/bolsa-de-trabajo-Tecnologico-de-Monterrey/|401  |
# |empleos/bolsa-de-trabajo-Michael-Page/            |360  |
# |empleos/bolsa-de-trabajo-BBVA-Bancomer/           |356  |
# +--------------------------------------------------+-----+
# only showing top 20 rows

# %%
sum = company_count.select(F.sum(F.col("count"))).collect()[0][0]
sum
# Out:
# 137284

# %%
from pyspark.sql.window import Window
ccp = company_count.withColumn("perc", F.col("count") / sum).orderBy(F.col("perc").desc())
window = Window.orderBy(F.col("perc").desc()).rowsBetween(Window.unboundedPreceding, Window.currentRow)
ccp.withColumn("cumsum", F.sum(F.col("perc")).over(window)).show(50, truncate=False)
# Out:
# +------------------------------------------------------------------------+-----+---------------------+-------------------+
# |url                                                                     |count|perc                 |cumsum             |
# +------------------------------------------------------------------------+-----+---------------------+-------------------+
# |null                                                                    |16764|0.12211182657847965  |0.12211182657847965|
# |empleos/bolsa-de-trabajo-Test-and-QA-Corporation/                       |9207 |0.06706535357361382  |0.18917718015209345|
# |empleos/bolsa-de-trabajo-grupo-salinas/                                 |7591 |0.05529413478628245  |0.2444713149383759 |
# |empleos/bolsa-de-trabajo-Un-Mejor-Empleo/                               |3190 |0.023236502432912795 |0.2677078173712887 |
# |empleos/bolsa-de-trabajo-Trabajos-Diarios-MX/                           |2985 |0.021743247574371377 |0.2894510649456601 |
# |empleos/bolsa-de-trabajo-Grupo-Salinas/                                 |1886 |0.013737944698581044 |0.3031890096442411 |
# |empleos/bolsa-de-trabajo-gepp/                                          |1572 |0.011450715305498092 |0.3146397249497392 |
# |empleos/bolsa-de-trabajo-truper/                                        |1452 |0.010576614900498237 |0.3252163398502374 |
# |empleos/bolsa-de-trabajo-Adecco/                                        |952  |0.006934529879665511 |0.33215086972990293|
# |empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/                        |916  |0.006672299758165554 |0.3388231694880685 |
# |empleos/bolsa-de-trabajo-Banamex/                                       |844  |0.006147839515165642 |0.34497100900323413|
# |empleos/bolsa-de-trabajo-Santander/                                     |763  |0.00555782174179074  |0.3505288307450249 |
# |empleos/bolsa-de-trabajo-Autofinauto/                                   |710  |0.005171760729582472 |0.35570059147460736|
# |empleos/bolsa-de-trabajo-CitiGroup/                                     |700  |0.005098919029165817 |0.3607995105037732 |
# |empleos/bolsa-de-trabajo-bairesdev/                                     |619  |0.004508901255790915 |0.3653084117595641 |
# |empleos/bolsa-de-trabajo-Banorte/                                       |492  |0.0035838116604994027|0.3688922234200635 |
# |empleos/bolsa-de-trabajo-Workable-ATS/                                  |439  |0.0031977506482911335|0.37208997406835465|
# |empleos/bolsa-de-trabajo-Tecnologico-de-Monterrey/                      |401  |0.0029209521867078463|0.3750109262550625 |
# |empleos/bolsa-de-trabajo-Michael-Page/                                  |360  |0.002622301214999563 |0.37763322747006206|
# |empleos/bolsa-de-trabajo-BBVA-Bancomer/                                 |356  |0.0025931645348329013|0.38022639200489494|
# |empleos/bolsa-de-trabajo-marriott-international/                        |349  |0.002542175344541243 |0.3827685673494362 |
# |empleos/bolsa-de-trabajo-EnsenadaHoy-com/                               |342  |0.0024911861542495847|0.3852597535036858 |
# |empleos/bolsa-de-trabajo-Michael-Page-Mexico/                           |334  |0.002432912793916261 |0.3876926662976021 |
# |empleos/bolsa-de-trabajo-Femsa/                                         |325  |0.002367355263541272 |0.39006002156114333|
# |empleos/bolsa-de-trabajo-Atento-Servicios--S--A--de-C-V-/               |310  |0.0022580927129162904|0.3923181142740596 |
# |empleos/bolsa-de-trabajo-Seguros-Inbursa--S-A-Grupo-Financiero-Inbursa/ |303  |0.002207103522624632 |0.39452521779668426|
# |empleos/bolsa-de-trabajo-Liverpool/                                     |301  |0.0021925351825413013|0.39671775297922557|
# |empleos/bolsa-de-trabajo-Grupo-Santander-Mexico/                        |299  |0.0021779668424579705|0.39889571982168354|
# |empleos/bolsa-de-trabajo-Grupo-Nacional-Provincial/                     |290  |0.0021124093120829814|0.40100812913376654|
# |empleos/bolsa-de-trabajo-Worken/                                        |288  |0.00209784097199965  |0.4031059701057662 |
# |empleos/bolsa-de-trabajo-Profuturo/                                     |285  |0.002075988461874654 |0.4051819585676409 |
# |empleos/bolsa-de-trabajo-Teleperformance/                               |279  |0.0020322834416246615|0.40721424200926554|
# |empleos/bolsa-de-trabajo-banco-bilbao-vizcaya-argentaria/               |277  |0.0020177151015413303|0.40923195711080684|
# |empleos/bolsa-de-trabajo-Qualitas-Compania-de-Seguros/                  |266  |0.0019375892310830103|0.41116954634188985|
# |empleos/bolsa-de-trabajo-Continental-AG/                                |266  |0.0019375892310830103|0.41310713557297285|
# |empleos/bolsa-de-trabajo-Jabil/                                         |262  |0.0019084525509163485|0.4150155881238892 |
# |empleos/bolsa-de-trabajo-Probecarios-com/                               |261  |0.001901168380874683 |0.4169167565047639 |
# |empleos/bolsa-de-trabajo-American-Eagle-Outfitters/                     |260  |0.0018938842108330177|0.4188106407155969 |
# |empleos/bolsa-de-trabajo-Cemex-Holdings/                                |246  |0.0017919058302497013|0.4206025465458466 |
# |empleos/bolsa-de-trabajo-pepsico/                                       |244  |0.0017773374901663705|0.422379884036013  |
# |empleos/bolsa-de-trabajo-Sociedad-Nacional-Promotora-de-Becarios-S-C-/  |241  |0.001755484980041374 |0.42413536901605436|
# |empleos/bolsa-de-trabajo-CREDICLUB-SA-DE-CV-SOCIEDAD-FINANCIERA-POPULAR/|238  |0.0017336324699163777|0.42586900148597073|
# |empleos/bolsa-de-trabajo-Gentera/                                       |236  |0.0017190641298330468|0.42758806561580376|
# |empleos/bolsa-de-trabajo-Softtek/                                       |223  |0.001624369919291396 |0.42921243553509514|
# |empleos/bolsa-de-trabajo-VincuVentas-MX/                                |222  |0.0016170857492497305|0.4308295212843449 |
# |empleos/bolsa-de-trabajo-abb-holdings-inc/                              |222  |0.0016170857492497305|0.4324466070335946 |
# |empleos/bolsa-de-trabajo-Bosch-Group/                                   |218  |0.0015879490690830687|0.43403455610267766|
# |empleos/bolsa-de-trabajo-flex-ltd-/                                     |217  |0.0015806648990414032|0.43561522100171907|
# |empleos/bolsa-de-trabajo-Herramientas-Truper/                           |216  |0.0015733807289997378|0.43718860173071883|
# |empleos/bolsa-de-trabajo-Grupo-Gayosso/                                 |205  |0.0014932548585414177|0.43868185658926023|
# +------------------------------------------------------------------------+-----+---------------------+-------------------+
# only showing top 50 rows

# %%
df.where("company.url='empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/'").count()
# Out:
# 916

# %%
df.select("company.name").where("company.confidential=TRUE").count()
# Out:
# 16764

# %%
company_count = df.where("redirect.type != 2").groupby("company.url").count().sort(F.col("count").desc())
company_count.show(truncate=False)
# Out:
# +-----------------------------------------------------------------------+-----+
# |url                                                                    |count|
# +-----------------------------------------------------------------------+-----+
# |null                                                                   |16188|
# |empleos/bolsa-de-trabajo-Grupo-Salinas/                                |1886 |
# |empleos/bolsa-de-trabajo-Adecco/                                       |952  |
# |empleos/bolsa-de-trabajo-Manpower--S-A--de-C-V-/                       |916  |
# |empleos/bolsa-de-trabajo-Banamex/                                      |844  |
# |empleos/bolsa-de-trabajo-Autofinauto/                                  |710  |
# |empleos/bolsa-de-trabajo-Banorte/                                      |492  |
# |empleos/bolsa-de-trabajo-Santander/                                    |466  |
# |empleos/bolsa-de-trabajo-Michael-Page/                                 |360  |
# |empleos/bolsa-de-trabajo-BBVA-Bancomer/                                |356  |
# |empleos/bolsa-de-trabajo-Femsa/                                        |325  |
# |empleos/bolsa-de-trabajo-Atento-Servicios--S--A--de-C-V-/              |310  |
# |empleos/bolsa-de-trabajo-Seguros-Inbursa--S-A-Grupo-Financiero-Inbursa/|303  |
# |empleos/bolsa-de-trabajo-Liverpool/                                    |301  |
# |empleos/bolsa-de-trabajo-Grupo-Nacional-Provincial/                    |290  |
# |empleos/bolsa-de-trabajo-Profuturo/                                    |285  |
# |empleos/bolsa-de-trabajo-Teleperformance/                              |279  |
# |empleos/bolsa-de-trabajo-Qualitas-Compania-de-Seguros/                 |266  |
# |empleos/bolsa-de-trabajo-Sociedad-Nacional-Promotora-de-Becarios-S-C-/ |241  |
# |empleos/bolsa-de-trabajo-Worken/                                       |240  |
# +-----------------------------------------------------------------------+-----+
# only showing top 20 rows

# %%
company_count = df.where("redirect.type == 2").groupby("company.url").count().sort(F.col("count").desc())
company_count.show(truncate=False)
# Out:
# +---------------------------------------------------------+-----+
# |url                                                      |count|
# +---------------------------------------------------------+-----+
# |empleos/bolsa-de-trabajo-Test-and-QA-Corporation/        |9207 |
# |empleos/bolsa-de-trabajo-grupo-salinas/                  |7591 |
# |empleos/bolsa-de-trabajo-Un-Mejor-Empleo/                |3190 |
# |empleos/bolsa-de-trabajo-Trabajos-Diarios-MX/            |2985 |
# |empleos/bolsa-de-trabajo-gepp/                           |1572 |
# |empleos/bolsa-de-trabajo-truper/                         |1452 |
# |empleos/bolsa-de-trabajo-CitiGroup/                      |700  |
# |empleos/bolsa-de-trabajo-bairesdev/                      |619  |
# |null                                                     |576  |
# |empleos/bolsa-de-trabajo-Workable-ATS/                   |439  |
# |empleos/bolsa-de-trabajo-marriott-international/         |349  |
# |empleos/bolsa-de-trabajo-EnsenadaHoy-com/                |342  |
# |empleos/bolsa-de-trabajo-Michael-Page-Mexico/            |334  |
# |empleos/bolsa-de-trabajo-Grupo-Santander-Mexico/         |299  |
# |empleos/bolsa-de-trabajo-Santander/                      |297  |
# |empleos/bolsa-de-trabajo-Tecnologico-de-Monterrey/       |286  |
# |empleos/bolsa-de-trabajo-banco-bilbao-vizcaya-argentaria/|277  |
# |empleos/bolsa-de-trabajo-Continental-AG/                 |266  |
# |empleos/bolsa-de-trabajo-Jabil/                          |262  |
# |empleos/bolsa-de-trabajo-Probecarios-com/                |261  |
# +---------------------------------------------------------+-----+
# only showing top 20 rows

# %%
df.where("company.url == 'empleos/bolsa-de-trabajo-bairesdev/'").first()
# Out:
# Row(Job:value='Job:17036943', __typename='Job', applied=False, autoinclusion=Row(__typename='JobAutoinclusion', autoinclusion=True, source='asp'), bullets=[], category=Row(__ref='JobCategory:17'), company=Row(__typename='JobCompany', confidential=False, logoUrl='https://cdn-h4.occ.com.mx/images/logos/300x300/01/01RfAPA_ZZ_STrdMpwQ-DQ2.jpg', name='bairesdev', namePretty='bairesdev', profile=None, rel=None, url='empleos/bolsa-de-trabajo-bairesdev/'), contact=Row(__typename='JobContact', emailAddress='', name='', phoneNumber='', showContactInfo=False), dates=Row(__typename='JobDates', active='2023-07-23 20:52:32', expires='2023-07-25 00:00:00', publish='2023-07-12 00:00:00'), description='Who We are   BairesDev is proud to be the fastest-growing company in America. With people in five continents and world-class clients, we are only as strong as the multicultural teams at the heart of o ...', education=Row(__typename='JobEducation', level='NOT_SPECIFIED', url='empleos/nivel-posgrado/'), friendlyId='17036943-big-data-tech-lead-remote-work', googleForJobs=Row(__typename='GoogleForJobs', isGoogleForJobs=True, isGoogleIndexed=True), hiring=Row(__typename='JobHiring', contract=False, fullTime=False, partTime=False, permanent=True, temporary=False, url='empleos/permanente/'), id='17036943', jobBody='Who We are<br> <br>BairesDev is proud to be the fastest-growing company in America. With people in five continents and world-class clients, we are only as strong as the multicultural teams at the heart of our business. To consistently deliver the highest quality solutions to our clients, we only hire the Top 1% of the best talents and nurture their professional growth on exciting projects. <br><br>Big Data Tech Lead at BairesDev<br> <br>We are looking for Big Data Tech Leads to join our Development team and participate in different projects made up of multicultural teams distributed worldwide. We are looking for proactive people and team players passionate about programming in this language and oriented to provide the best experience to the end user. This is an excellent opportunity for those professionals looking to develop in one of the fastest-growing companies in the industry!<br> <br>These developers will face numerous technical challenges, so they must use current technologies and get involved in the mobile world, web applications, devices, etc.<br><br>What You Will Do:<br> <br>- Use leading open-source big-data tools like Spark, Hadoop, Scala, and Elasticsearch. You should be comfortable working with high-profile clients on their sites.<BR>- Providing technical leadership to a team of Data Engineers and Data Scientists to ensure efficient and effective delivery of reusable solutions.<BR>- Managing, transforming and cleansing high-volume data into Quantexa Entities and Networks.<BR>- Writing defensive, fault-tolerant and efficient code for data processing.<BR>- Developing scoring algorithms to identify high-risk activities.<br><br>Here&#39;s what we are looking for:<br> <br>- 10+ years of experience working as a developer.<BR>- 7+ years of experience in Big Data.<BR>- Proficient with analysis, troubleshooting, and problem-solving.<BR>- Hands-on experience with managing data loads and data quality is a plus.<BR>- Advanced English level.<br><br>How we do make your work (and your life) easier:<br> <br>- 100% remote work.<BR>- Hardware setup for you to work from home.<BR>- Flexible hours - make your schedule.<BR>- Paid parental leave, vacation & holidays.<BR>- Diverse and multicultural work environment.<BR>- An innovative environment with the structure and resources of a leading multinational.<BR>- Excellent compensation - well above the market average.<BR>- Here you can grow at the speed of your learning curve.<br><br>Our people work remotely but with a consistent and robust culture that promotes diversity and teamwork. To continue being the leading software development company in Latin America, we want to ensure that every BairesDev memb ...

# %%
df.where("redirect.isRedirected == TRUE").where("autoinclusion.autoinclusion == TRUE").count()
# Out:
# 56294

# %%
df.where("redirect.isRedirected == TRUE").where("autoinclusion.autoinclusion == FALSE").count()
# Out:
# 2178

# %%
df.where("redirect.isRedirected == FALSE").where("autoinclusion.autoinclusion == TRUE").count()
# Out:
# 0

# %%
df.where("redirect.isRedirected == FALSE").where("autoinclusion.autoinclusion == FALSE").count()
# Out:
# 78812

# %%
df.where("redirect.isRedirected == TRUE")\
    .where("autoinclusion.autoinclusion == TRUE")\
    .select(["scraped_url", "redirect.externalUrl"])\
    .show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------+-----------------------------------------------------------+
# |scraped_url                                                                          |externalUrl                                                |
# +-------------------------------------------------------------------------------------+-----------------------------------------------------------+
# |https://www.occ.com.mx/empleo/oferta/16979014-senior-contract-administrator/         |https://careers.wbd.com/global/en/job/R000070127           |
# |https://www.occ.com.mx/empleo/oferta/17011509-senior-software-developer-web-sdk/     |https://paypal.eightfold.ai/careers/job?pid=274894789183   |
# |https://www.occ.com.mx/empleo/oferta/16185010-medico-general/                        |https://empleo.gob.mx/resultados-ss-detalle/empleo/20220541|
# |https://www.occ.com.mx/empleo/oferta/17074718-carboy/                                |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367400|
# |https://www.occ.com.mx/empleo/oferta/17074716-secretaria/                            |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367397|
# |https://www.occ.com.mx/empleo/oferta/17074723-preventista/                           |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367410|
# |https://www.occ.com.mx/empleo/oferta/17074731-recepcionista/                         |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367429|
# |https://www.occ.com.mx/empleo/oferta/17074714-ayudante-de-chofer/                    |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367394|
# |https://www.occ.com.mx/empleo/oferta/17074722-asesor-financiero/                     |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367408|
# |https://www.occ.com.mx/empleo/oferta/17074715-lavador-de-tinacos/                    |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367395|
# |https://www.occ.com.mx/empleo/oferta/17074727-tecnico-instalador/                    |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367420|
# |https://www.occ.com.mx/empleo/oferta/17074717-supervisor-de-ventas/                  |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367399|
# |https://www.occ.com.mx/empleo/oferta/17074721-t-xc3-xa9cnico-plomero/                |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367407|
# |https://www.occ.com.mx/empleo/oferta/17074713-contador-p-xc3-xbablico/               |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367393|
# |https://www.occ.com.mx/empleo/oferta/17074726-auxiliar-administrativo/               |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367418|
# |https://www.occ.com.mx/empleo/oferta/17074725-consultor-right-management/            |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367414|
# |https://www.occ.com.mx/empleo/oferta/17074712-ayudante-general-en-chiapas/           |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367391|
# |https://www.occ.com.mx/empleo/oferta/17074724-tecnico-a-construccion-de-fibra-optica/|https://empleo.gob.mx/resultados-ss-detalle/empleo/20367411|
# |https://www.occ.com.mx/empleo/oferta/17074765-ayudante-de-tecnico-de-montacargas/    |https://empleo.gob.mx/resultados-ss-detalle/empleo/20367498|
# |https://www.occ.com.mx/empleo/oferta/17069965-ventas/                                |https://empleo.gob.mx/resultados-ss-detalle/empleo/20366767|
# +-------------------------------------------------------------------------------------+-----------------------------------------------------------+
# only showing top 20 rows
